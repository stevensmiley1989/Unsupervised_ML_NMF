# %% [markdown]
# # Final - DTSA 5510
# ## Problem Statement
# My goal with this analysis is to determine if the Vaccine Adverse Event Reporting System (VAERS) data can help predict a patient's outcome given their adverse symptoms or other relevant information from taking a given vaccine.  This will be a binary classification problem where the model's made will determine if the patient DIED (y=1) or LIVED (y=0) from their adverse event report.  However, I want to try using NMF with Unsupervised Machine Learning to solve this problem.
# I am solving this problem in order to better understand the severity of adverse reactions people can have from certain vaccines.

# %% [markdown]
# # 1. Exploratory Data Analysis (EDA)
#
# **Dataset**: “VAERS Data Sets”
#
#
# **Dataset Source**: https://vaers.hhs.gov/data/datasets.html
#
#
#
# **Key attributes/dimensions of the data**:
# There are 3 main CSV files associated with this dataset:
# 1)	*VAERSDATA.csv
# 2)	*VAERSSYMPTOMS.csv
# 3)	*VAERSVAX.csv
#
# These CSV files contain numbers, dates, and other unique values that can be mapped to their Vaccine Adverse Event Reporting System (VAERS) identification number for each person among the spreadsheets.  The VAERS was made by the Food and Drug Administration (FDA) and the Centers for Disease Control and Prevention (CDC) to collect data on adverse reactions that could be associated with vaccines in general.
#
# I pulled this data on 9/6/2024, which stated the data contains VAERS reports processed as of **08/30/2024**.
#
# I filtered to only include those vaccines related to COVID19.  This dataset includes false positives for adverse reactions given a vaccine due to the encouragement towards doctors and other vaccine providers to report any adverse event if seen regardless of if they can prove the vaccine was the cause.  Therefore, the dataset contains a combination of coincidental events and those truly caused by the vaccine.
#
# The dataset I downloaded I have shared here on my GDRIVE for people to reproduce my work:
#
# https://drive.google.com/file/d/13ft2QazL4OugjftllcwjPXLUVMB8-2Xi/view?usp=drive_link

# %% [markdown]
# ## 1.1 Import Libraries

# %%
import os
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import make_scorer
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from sklearn.model_selection import GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin
import itertools
from sklearn.metrics import accuracy_score
from nltk.corpus import stopwords
import re
import pandas as pd
from nltk.tokenize import word_tokenize
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import altair as alt
import warnings
from sklearn.preprocessing import OneHotEncoder,  StandardScaler
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1.2 Read in Data

# %%
MAIN_DIRS = "AllVAERSDataCSVS"
ALL_CSVS = os.listdir(MAIN_DIRS)
VAERSDATA_CSVS = [w for w in ALL_CSVS if w.find("DATA")!=-1 and w.lower().find("nondomestic")==-1]
VAERSSYMP_CSVS = [w for w in ALL_CSVS if w.find("SYMPTOMS")!=-1 and w.lower().find("nondomestic")==-1]
VAERSVAX_CSVS = [w for w in ALL_CSVS if w.find("VAX")!=-1 and w.lower().find("nondomestic")==-1]

# %%
for i in range(len(VAERSDATA_CSVS)):
    if i==0:
        df_VAERSDATA = pd.read_csv(os.path.join(MAIN_DIRS,VAERSDATA_CSVS[i]),encoding='ISO-8859-1')
    else:
        df_i = pd.read_csv(os.path.join(MAIN_DIRS,VAERSDATA_CSVS[i]),encoding='ISO-8859-1')
        df_VAERSDATA = pd.concat([df_VAERSDATA,df_i],axis=0)
        df_VAERSDATA = df_VAERSDATA.reset_index().drop("index",axis=1)

# %%
df_VAERSDATA
# Out:
#          VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX  \
# 0           25001  07/02/1990    WI     0.20      NaN      NaN   F
# 1           25003  07/02/1990    TX     0.80      NaN      NaN   M
# 2           25004  07/02/1990    NY     0.90      NaN      NaN   M
# 3           25005  07/02/1990    OK      NaN      NaN      NaN   U
# 4           25006  07/02/1990    OH    16.00     16.0      NaN   F
# ...           ...         ...   ...      ...      ...      ...  ..
# 1855857   2787668  08/30/2024    IN    37.00     37.0      NaN   F
# 1855858   2787674  08/30/2024    GA     0.25      0.0      0.3   U
# 1855859   2787675  08/30/2024    NY      NaN      NaN      NaN   F
# 1855860   2787676  08/30/2024    KS     0.17      0.0      0.2   M
# 1855861   2787679  08/30/2024    TX     4.00      4.0      NaN   M
#
#            RPT_DATE                                       SYMPTOM_TEXT DIED  \
# 0               NaN  Loud intense cry with screaming for 1 1/2 hrs....  NaN
# 1               NaN  Hypotonic, Hyporesponsive episode, Infant died...    Y
# 2               NaN  Pt developed chills for approx. 1 hr, felt ach...  NaN
# 3               NaN  7 patients within 2 weeks have reported joint ...  NaN
# 4               NaN  16 yr old female feeling faint & then had seiz...  NaN
# ...             ...                                                ...  ...
# 1855857         NaN  Skin reactions, allergies, muscle weakness, bo...  NaN
# 1855858         NaN  No additional AE/No PQC.; HCP reported that RE...  NaN
# 1855859         NaN  Shingles outbreak after vaccination; This non-...  NaN
# 1855860         NaN  nurse stated that she accidentally gave ACTHIB...  NaN
# 1855861  08/26/2024                                   Redness Swelling  NaN
#
#          ... CUR_ILL                                            HISTORY  \
# 0        ...     NaN                                                NaN
# 1        ...     NaN                                                NaN
# 2        ...     NaN                                                NaN
# 3        ...     NaN                                                NaN
# 4        ...     NaN                    no hx of local or systemic rxns
# ...      ...     ...                                                ...
# 1855857  ...     NaN  Arthrisis, mild- moderate headaches, endometri...
# 1855858  ...     NaN                                                NaN
# 1855859  ...     NaN                                                NaN
# 1855860  ...     NaN                                                NaN
# 1855861  ...     NaN                                                NaN
#
#                  PRIOR_VAX                  SPLTTYPE  FORM_VERS TODAYS_DATE  \
# 0                      NaN                       NaN          1         NaN
# 1        ~ ()~~~In patient                       NaN          1         NaN
# 2        ~ ()~~~In patient                 890269201          1         NaN
# 3        ~ ()~~~In patient                 890277901          1         NaN
# 4        ~ ()~~~In patient                 890278001          1         NaN
# ...                    ...                       ...        ...         ...
# 1855857                NaN                       NaN          2  08/30/2024
# 1855858                NaN  US0095075132408USA010106          2  08/30/2024
# 1855859                NaN         USGSKUS2024105377          2  08/30/2024
# 1855860                NaN          USSA2024SA252142          2  08/30/2024
# 1855861                NaN                       NaN          1         NaN
#
#         BIRTH_DEFECT OFC_VISIT ER_ED_VISIT ALLERGIES
# 0                NaN       NaN         NaN       NaN
# 1                NaN       NaN         NaN       NaN
# 2                NaN       NaN         NaN       NaN
# 3                NaN       NaN         NaN       NaN
# 4                NaN       NaN         NaN       NaN
# ...              ...       ...         ...       ...
# 1855857            Y         Y         NaN  Tramadol
# 1855858          NaN       NaN         NaN       NaN
# 1855859          NaN       NaN         NaN       NaN
# 1855860          NaN       NaN         NaN       NaN
# 1855861          NaN       NaN         NaN       NaN
#
# [1855862 rows x 35 columns]

# %%
for i in range(len(VAERSSYMP_CSVS)):
    if i==0:
        df_VAERSSYMPTOMS = pd.read_csv(os.path.join(MAIN_DIRS,VAERSSYMP_CSVS[i]),encoding='ISO-8859-1')
    else:
        df_i = pd.read_csv(os.path.join(MAIN_DIRS,VAERSSYMP_CSVS[i]),encoding='ISO-8859-1')
        df_VAERSSYMPTOMS = pd.concat([df_VAERSSYMPTOMS,df_i],axis=0)
        df_VAERSSYMPTOMS = df_VAERSSYMPTOMS.reset_index().drop("index",axis=1)

# %%
df_VAERSSYMPTOMS
# Out:
#          VAERS_ID                                  SYMPTOM1  SYMPTOMVERSION1  \
# 0           25001                                 Agitation              8.1
# 1           25003                                  Delirium              8.1
# 2           25004                                    Chills              8.1
# 3           25005                                 Arthritis              8.1
# 4           25006                                Convulsion              8.1
# ...           ...                                       ...              ...
# 2362321   2787677                             Muscle spasms             27.0
# 2362322   2787677                       Physical disability             27.0
# 2362323   2787677  Wrong technique in product usage process             27.0
# 2362324   2787678                                  Tinnitus             27.0
# 2362325   2787679                                  Erythema             27.0
#
#                                            SYMPTOM2  SYMPTOMVERSION2  \
# 0                                               NaN              NaN
# 1                                       Hypokinesia              8.1
# 2                                Dermatitis contact              8.1
# 3                             Injection site oedema              8.1
# 4                                         Dizziness              8.1
# ...                                             ...              ...
# 2362321                   Musculoskeletal stiffness             27.0
# 2362322  Product administered at inappropriate site             27.0
# 2362323                         X-ray limb abnormal             27.0
# 2362324                                         NaN              NaN
# 2362325                                    Swelling             27.0
#
#                                                   SYMPTOM3  SYMPTOMVERSION3  \
# 0                                                      NaN              NaN
# 1                                                Hypotonia              8.1
# 2                                           Oedema genital              8.1
# 3                                  Injection site reaction              8.1
# 4                                                      NaN              NaN
# ...                                                    ...              ...
# 2362321                                               Pain             27.0
# 2362322  Shoulder injury related to vaccine administration             27.0
# 2362323                                                NaN              NaN
# 2362324                                                NaN              NaN
# 2362325                                                NaN              NaN
#
#                   SYMPTOM4  SYMPTOMVERSION4       SYMPTOM5  SYMPTOMVERSION5
# 0                      NaN              NaN            NaN              NaN
# 1                      NaN              NaN            NaN              NaN
# 2              Pelvic pain              8.1            NaN              NaN
# 3                      NaN              NaN            NaN              NaN
# 4                      NaN              NaN            NaN              NaN
# ...                    ...              ...            ...              ...
# 2362321  Pain in extremity             27.0  Periarthritis             27.0
# 2362322     Sleep disorder             27.0     Tendonitis             27.0
# 2362323                NaN              NaN            NaN              NaN
# 2362324                NaN              NaN            NaN              NaN
# 2362325                NaN              NaN            NaN              NaN
#
# [2362326 rows x 11 columns]

# %%
for i in range(len(VAERSVAX_CSVS)):
    if i==0:
        df_VAERSVAX = pd.read_csv(os.path.join(MAIN_DIRS,VAERSVAX_CSVS[i]),encoding='ISO-8859-1')
    else:
        df_i = pd.read_csv(os.path.join(MAIN_DIRS,VAERSVAX_CSVS[i]),encoding='ISO-8859-1')
        df_VAERSVAX = pd.concat([df_VAERSVAX,df_i],axis=0)
        df_VAERSVAX = df_VAERSVAX.reset_index().drop("index",axis=1)

# %%
df_VAERSVAX
# Out:
#          VAERS_ID VAX_TYPE                           VAX_MANU  VAX_LOT  \
# 0           25001      DTP             CONNAUGHT LABORATORIES  9Q01042
# 1           25003      DTP               LEDERLE LABORATORIES   259962
# 2           25003      OPV                       PFIZER\WYETH   241950
# 3           25004      OPV                       PFIZER\WYETH   232961
# 4           25005       TD               LEDERLE LABORATORIES   247955
# ...           ...      ...                                ...      ...
# 2333262   2787678     MENB  NOVARTIS VACCINES AND DIAGNOSTICS    G334J
# 2333263   2787678      MNQ                     SANOFI PASTEUR  U8284AB
# 2333264   2787679  DTAPIPV                     SANOFI PASTEUR  U8009AB
# 2333265   2787679      MMR                   MERCK & CO. INC.  X019107
# 2333266   2787679   VARCEL                   MERCK & CO. INC.  Y00389Z
#
#         VAX_DOSE_SERIES VAX_ROUTE VAX_SITE  \
# 0                   UNK        IM      NaN
# 1                     4        IM      NaN
# 2                     4        PO       MO
# 3                   UNK       NaN      NaN
# 4                   UNK        IM      NaN
# ...                 ...       ...      ...
# 2333262               1       NaN       RA
# 2333263             UNK       NaN       LA
# 2333264             UNK        IM       LL
# 2333265             UNK        SC       RL
# 2333266             UNK        SC       LL
#
#                                     VAX_NAME
# 0                        DTP (NO BRAND NAME)
# 1                          DTP (TRI-IMMUNOL)
# 2                POLIO VIRUS, ORAL (ORIMUNE)
# 3                POLIO VIRUS, ORAL (ORIMUNE)
# 4                TD ADSORBED (NO BRAND NAME)
# ...                                      ...
# 2333262            MENINGOCOCCAL B (BEXSERO)
# 2333263  MENINGOCOCCAL CONJUGATE (MENQUADFI)
# 2333264               DTAP + IPV (QUADRACEL)
# 2333265   MEASLES + MUMPS + RUBELLA (MMR II)
# 2333266                  VARICELLA (VARIVAX)
#
# [2333267 rows x 8 columns]

# %%
df_COMBINED = pd.merge(df_VAERSDATA,df_VAERSSYMPTOMS,on=["VAERS_ID"])
df_COMBINED = pd.merge(df_COMBINED,df_VAERSVAX,on=["VAERS_ID"])
df_COMBINED.head()
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0     25001  07/02/1990    WI      0.2      NaN      NaN   F      NaN
# 1     25003  07/02/1990    TX      0.8      NaN      NaN   M      NaN
# 2     25003  07/02/1990    TX      0.8      NaN      NaN   M      NaN
# 3     25004  07/02/1990    NY      0.9      NaN      NaN   M      NaN
# 4     25005  07/02/1990    OK      NaN      NaN      NaN   U      NaN
#
#                                         SYMPTOM_TEXT DIED  ...  \
# 0  Loud intense cry with screaming for 1 1/2 hrs....  NaN  ...
# 1  Hypotonic, Hyporesponsive episode, Infant died...    Y  ...
# 2  Hypotonic, Hyporesponsive episode, Infant died...    Y  ...
# 3  Pt developed chills for approx. 1 hr, felt ach...  NaN  ...
# 4  7 patients within 2 weeks have reported joint ...  NaN  ...
#
#   SYMPTOMVERSION4 SYMPTOM5 SYMPTOMVERSION5 VAX_TYPE                VAX_MANU  \
# 0             NaN      NaN             NaN      DTP  CONNAUGHT LABORATORIES
# 1             NaN      NaN             NaN      DTP    LEDERLE LABORATORIES
# 2             NaN      NaN             NaN      OPV            PFIZER\WYETH
# 3             8.1      NaN             NaN      OPV            PFIZER\WYETH
# 4             NaN      NaN             NaN       TD    LEDERLE LABORATORIES
#
#    VAX_LOT VAX_DOSE_SERIES VAX_ROUTE VAX_SITE                     VAX_NAME
# 0  9Q01042             UNK        IM      NaN          DTP (NO BRAND NAME)
# 1   259962               4        IM      NaN            DTP (TRI-IMMUNOL)
# 2   241950               4        PO       MO  POLIO VIRUS, ORAL (ORIMUNE)
# 3   232961             UNK       NaN      NaN  POLIO VIRUS, ORAL (ORIMUNE)
# 4   247955             UNK        IM      NaN  TD ADSORBED (NO BRAND NAME)
#
# [5 rows x 52 columns]

# %%
df_COMBINED = df_COMBINED.drop_duplicates(["SYMPTOM_TEXT"])

# %%
df_COMBINED["DAYS_to_DEATH"] = pd.to_datetime(df_COMBINED.DATEDIED) - pd.to_datetime(df_COMBINED.VAX_DATE)
df_COMBINED["DAYS_to_DEATH"] = df_COMBINED["DAYS_to_DEATH"] /np.timedelta64(1,"D")

# %%
df_COMBINED = df_COMBINED.reset_index().drop("index",axis=1)
df_COMBINED
# Out:
#          VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0           25001  07/02/1990    WI     0.20      NaN      NaN   F      NaN
# 1           25003  07/02/1990    TX     0.80      NaN      NaN   M      NaN
# 2           25004  07/02/1990    NY     0.90      NaN      NaN   M      NaN
# 3           25005  07/02/1990    OK      NaN      NaN      NaN   U      NaN
# 4           25006  07/02/1990    OH    16.00     16.0      NaN   F      NaN
# ...           ...         ...   ...      ...      ...      ...  ..      ...
# 1729649   2787665  08/30/2024    OK     4.00      NaN      NaN   U      NaN
# 1729650   2787668  08/30/2024    IN    37.00     37.0      NaN   F      NaN
# 1729651   2787674  08/30/2024    GA     0.25      0.0      0.3   U      NaN
# 1729652   2787675  08/30/2024    NY      NaN      NaN      NaN   F      NaN
# 1729653   2787676  08/30/2024    KS     0.17      0.0      0.2   M      NaN
#
#                                               SYMPTOM_TEXT DIED  ...  \
# 0        Loud intense cry with screaming for 1 1/2 hrs....  NaN  ...
# 1        Hypotonic, Hyporesponsive episode, Infant died...    Y  ...
# 2        Pt developed chills for approx. 1 hr, felt ach...  NaN  ...
# 3        7 patients within 2 weeks have reported joint ...  NaN  ...
# 4        16 yr old female feeling faint & then had seiz...  NaN  ...
# ...                                                    ...  ...  ...
# 1729649  there are no symptomatic adverse events report...  NaN  ...
# 1729650  Skin reactions, allergies, muscle weakness, bo...  NaN  ...
# 1729651  No additional AE/No PQC.; HCP reported that RE...  NaN  ...
# 1729652  Shingles outbreak after vaccination; This non-...  NaN  ...
# 1729653  nurse stated that she accidentally gave ACTHIB...  NaN  ...
#
#           SYMPTOM5 SYMPTOMVERSION5    VAX_TYPE                     VAX_MANU  \
# 0              NaN             NaN         DTP       CONNAUGHT LABORATORIES
# 1              NaN             NaN         DTP         LEDERLE LABORATORIES
# 2              NaN             NaN         OPV                 PFIZER\WYETH
# 3              NaN             NaN          TD         LEDERLE LABORATORIES
# 4              NaN             NaN         MMR         UNKNOWN MANUFACTURER
# ...            ...             ...         ...                          ...
# 1729649        NaN             NaN        HPV9             MERCK & CO. INC.
# 1729650  Arthritis            27.0     COVID19              PFIZER\BIONTECH
# 1729651        NaN             NaN  DTAPHEPBIP  GLAXOSMITHKLINE BIOLOGICALS
# 1729652        NaN             NaN      VARZOS  GLAXOSMITHKLINE BIOLOGICALS
# 1729653        NaN             NaN        HIBV               SANOFI PASTEUR
#
#          VAX_LOT VAX_DOSE_SERIES VAX_ROUTE VAX_SITE  \
# 0        9Q01042             UNK        IM      NaN
# 1         259962               4        IM      NaN
# 2         232961             UNK       NaN      NaN
# 3         247955             UNK        IM      NaN
# 4            NaN             UNK       NaN      NaN
# ...          ...             ...       ...      ...
# 1729649  W015894             UNK       NaN      NaN
# 1729650   Ew0153               1        IM       LA
# 1729651      NaN             UNK       NaN      NaN
# 1729652      UNK             UNK       NaN      NaN
# 1729653  UK007AB               1        OT       RL
#
#                                           VAX_NAME DAYS_to_DEATH
# 0                              DTP (NO BRAND NAME)           NaN
# 1                                DTP (TRI-IMMUNOL)           NaN
# 2                      POLIO VIRUS, ORAL (ORIMUNE)           NaN
# 3                      TD ADSORBED (NO BRAND NAME)           NaN
# 4        MEASLES + MUMPS + RUBELLA (NO BRAND NAME)           NaN
# ...                                            ...           ...
# 1729649                           HPV (GARDASIL 9)           NaN
# 1729650        COVID19 (COVID19 (PFIZER-BIONTECH))           NaN
# 1729651               DTAP + HEPB + IPV (PEDIARIX)           NaN
# 1729652                          ZOSTER (SHINGRIX)           NaN
# 1729653                               HIB (ACTHIB)           NaN
#
# [1729654 rows x 53 columns]

# %%
sorted(list(df_COMBINED.columns))
# Out:
# ['AGE_YRS',
#  'ALLERGIES',
#  'BIRTH_DEFECT',
#  'CAGE_MO',
#  'CAGE_YR',
#  'CUR_ILL',
#  'DATEDIED',
#  'DAYS_to_DEATH',
#  'DIED',
#  'DISABLE',
#  'ER_ED_VISIT',
#  'ER_VISIT',
#  'FORM_VERS',
#  'HISTORY',
#  'HOSPDAYS',
#  'HOSPITAL',
#  'LAB_DATA',
#  'L_THREAT',
#  'NUMDAYS',
#  'OFC_VISIT',
#  'ONSET_DATE',
#  'OTHER_MEDS',
#  'PRIOR_VAX',
#  'RECOVD',
#  'RECVDATE',
#  'RPT_DATE',
#  'SEX',
#  'SPLTTYPE',
#  'STATE',
#  'SYMPTOM1',
#  'SYMPTOM2',
#  'SYMPTOM3',
#  'SYMPTOM4',
#  'SYMPTOM5',
#  'SYMPTOMVERSION1',
#  'SYMPTOMVERSION2',
#  'SYMPTOMVERSION3',
#  'SYMPTOMVERSION4',
#  'SYMPTOMVERSION5',
#  'SYMPTOM_TEXT',
#  'TODAYS_DATE',
#  'VAERS_ID',
#  'VAX_DATE',
#  'VAX_DOSE_SERIES',
#  'VAX_LOT',
#  'VAX_MANU',
#  'VAX_NAME',
#  'VAX_ROUTE',
#  'VAX_SITE',
#  'VAX_TYPE',
#  'V_ADMINBY',
#  'V_FUNDBY',
#  'X_STAY']

# %%
sorted(df_COMBINED.VAX_TYPE.unique())
# Out:
# ['6VAX-F',
#  'ADEN',
#  'ADEN_4_7',
#  'ANTH',
#  'BCG',
#  'CEE',
#  'CHIK',
#  'CHOL',
#  'COVID19',
#  'COVID19-2',
#  'DF',
#  'DPP',
#  'DT',
#  'DTAP',
#  'DTAPH',
#  'DTAPHEPBIP',
#  'DTAPIPV',
#  'DTAPIPVHIB',
#  'DTIPV',
#  'DTOX',
#  'DTP',
#  'DTPHEP',
#  'DTPHIB',
#  'DTPIHI',
#  'DTPIPV',
#  'DTPPHIB',
#  'DTPPVHBHPB',
#  'EBZR',
#  'FLU(H1N1)',
#  'FLU3',
#  'FLU4',
#  'FLUA3',
#  'FLUA4',
#  'FLUC3',
#  'FLUC4',
#  'FLUN(H1N1)',
#  'FLUN3',
#  'FLUN4',
#  'FLUR3',
#  'FLUR4',
#  'FLUX',
#  'FLUX(H1N1)',
#  'H5N1',
#  'HBHEPB',
#  'HBPV',
#  'HEP',
#  'HEPA',
#  'HEPAB',
#  'HEPATYP',
#  'HIBV',
#  'HPV2',
#  'HPV4',
#  'HPV9',
#  'HPVX',
#  'IPV',
#  'JEV',
#  'JEV1',
#  'JEVX',
#  'LYME',
#  'MEA',
#  'MEN',
#  'MENB',
#  'MENHIB',
#  'MER',
#  'MM',
#  'MMR',
#  'MMRV',
#  'MNP',
#  'MNQ',
#  'MNQHIB',
#  'MU',
#  'MUR',
#  'OPV',
#  'PER',
#  'PLAGUE',
#  'PNC',
#  'PNC10',
#  'PNC13',
#  'PNC15',
#  'PNC20',
#  'PPV',
#  'RAB',
#  'RSV',
#  'RUB',
#  'RV',
#  'RV1',
#  'RV5',
#  'RVX',
#  'SMALL',
#  'SMALLMNK',
#  'SSEV',
#  'TBE',
#  'TD',
#  'TDAP',
#  'TTOX',
#  'TYP',
#  'UNK',
#  'VARCEL',
#  'VARZOS',
#  'YF']

# %%
df_COVID = df_COMBINED[df_COMBINED.VAX_TYPE.str.lower().str.find("covid")!=-1]
df_COVID = df_COVID.reset_index().drop("index",axis=1)

# %%
df_COVID['VAX_MANU'] = df_COVID.groupby('VAX_LOT')['VAX_MANU'].transform(lambda x: x.mode()[0])

# %%
df_COVID['VAX_TYPE'] = df_COVID.groupby('VAX_LOT')['VAX_TYPE'].transform(lambda x: x.mode()[0])

# %%
df_COVID.to_csv("df_COVID.csv",index=None)

# %% [markdown]
# ## 1.3 Data Cleaning

# %%
df_COVID.describe()
# Out:
#            VAERS_ID        AGE_YRS        CAGE_YR      CAGE_MO      HOSPDAYS  \
# count  9.107910e+05  809846.000000  709781.000000  4258.000000  49154.000000
# mean   1.664290e+06      50.267979      49.882389     0.338633     10.544778
# std    5.330600e+05      19.821425      20.087632     0.330600    639.878373
# min    9.024180e+05       0.080000       0.000000     0.000000      1.000000
# 25%    1.201110e+06      35.000000      35.000000     0.000000      2.000000
# 50%    1.587323e+06      51.000000      51.000000     0.300000      4.000000
# 75%    2.075621e+06      66.000000      66.000000     0.600000      7.000000
# max    2.787668e+06     119.000000     120.000000     1.000000  99999.000000
#
#              NUMDAYS      FORM_VERS  SYMPTOMVERSION1  SYMPTOMVERSION2  \
# count  778506.000000  910791.000000    910791.000000    743379.000000
# mean       43.859819       1.998932        24.239516        24.241974
# std       610.399894       0.032667         0.652729         0.656992
# min         0.000000       1.000000        23.100000        23.100000
# 25%         0.000000       2.000000        24.000000        24.000000
# 50%         1.000000       2.000000        24.000000        24.000000
# 75%         8.000000       2.000000        24.100000        24.100000
# max     44224.000000       2.000000        27.000000        27.000000
#
#        SYMPTOMVERSION3  SYMPTOMVERSION4  SYMPTOMVERSION5  DAYS_to_DEATH
# count    573924.000000    432266.000000    324771.000000   14905.000000
# mean         24.228382        24.214482        24.226294     154.023818
# std           0.647661         0.637458         0.645407     846.582838
# min          23.100000        23.100000        23.100000  -36523.000000
# 25%          24.000000        24.000000        24.000000      13.000000
# 50%          24.000000        24.000000        24.000000      86.000000
# 75%          24.100000        24.100000        24.100000     231.000000
# max          27.000000        27.000000        27.000000   36896.000000

# %%
print(df_COVID.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 910791 entries, 0 to 910790
# Data columns (total 53 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAERS_ID         910791 non-null  int64
#  1   RECVDATE         910791 non-null  object
#  2   STATE            769136 non-null  object
#  3   AGE_YRS          809846 non-null  float64
#  4   CAGE_YR          709781 non-null  float64
#  5   CAGE_MO          4258 non-null    float64
#  6   SEX              910791 non-null  object
#  7   RPT_DATE         902 non-null     object
#  8   SYMPTOM_TEXT     910791 non-null  object
#  9   DIED             17244 non-null   object
#  10  DATEDIED         15226 non-null   object
#  11  L_THREAT         14897 non-null   object
#  12  ER_VISIT         137 non-null     object
#  13  HOSPITAL         79771 non-null   object
#  14  HOSPDAYS         49154 non-null   float64
#  15  X_STAY           492 non-null     object
#  16  DISABLE          18058 non-null   object
#  17  RECOVD           829181 non-null  object
#  18  VAX_DATE         837843 non-null  object
#  19  ONSET_DATE       816422 non-null  object
#  20  NUMDAYS          778506 non-null  float64
#  21  LAB_DATA         313737 non-null  object
#  22  V_ADMINBY        910791 non-null  object
#  23  V_FUNDBY         973 non-null     object
#  24  OTHER_MEDS       454499 non-null  object
#  25  CUR_ILL          251783 non-null  object
#  26  HISTORY          468106 non-null  object
#  27  PRIOR_VAX        46534 non-null   object
#  28  SPLTTYPE         312288 non-null  object
#  29  FORM_VERS        910791 non-null  int64
#  30  TODAYS_DATE      903843 non-null  object
#  31  BIRTH_DEFECT     609 non-null     object
#  32  OFC_VISIT        191564 non-null  object
#  33  ER_ED_VISIT      114172 non-null  object
#  34  ALLERGIES        358995 non-null  object
#  35  SYMPTOM1         910791 non-null  object
#  36  SYMPTOMVERSION1  910791 non-null  float64
#  37  SYMPTOM2         743379 non-null  object
#  38  SYMPTOMVERSION2  743379 non-null  float64
#  39  SYMPTOM3         573924 non-null  object
#  40  SYMPTOMVERSION3  573924 non-null  float64
#  41  SYMPTOM4         432266 non-null  object
#  42  SYMPTOMVERSION4  432266 non-null  float64
#  43  SYMPTOM5         324771 non-null  object
#  44  SYMPTOMVERSION5  324771 non-null  float64
#  45  VAX_TYPE         632572 non-null  object
#  46  VAX_MANU         632572 non-null  object
#  47  VAX_LOT          632572 non-null  object
#  48  VAX_DOSE_SERIES  906594 non-null  object
#  49  VAX_ROUTE        687779 non-null  object
#  50  VAX_SITE         648406 non-null  object
#  51  VAX_NAME         910791 non-null  object
#  52  DAYS_to_DEATH    14905 non-null   float64
# dtypes: float64(11), int64(2), object(40)
# memory usage: 368.3+ MB
# None

# %%
#We can assume 'UNKNOWN' for object or str types that we dont know otherwise.
df_COVID['SEX'].fillna('Unknown', inplace=True) 
df_COVID['STATE'].fillna('Unknown', inplace=True)
df_COVID['VAX_LOT'].fillna('Unknown', inplace=True)
df_COVID['VAX_MANU'].fillna('Unknown', inplace=True)
df_COVID['VAX_SITE'].fillna('Unknown', inplace=True)
df_COVID['AGE_YRS'].fillna(df_COVID['AGE_YRS'].median(), inplace=True) #assume that the median age can be imputed for these values
df_COVID['ALLERGIES'].fillna('', inplace=True)  
df_COVID['HISTORY'].fillna('', inplace=True)  
df_COVID['CUR_ILL'].fillna('', inplace=True)  
df_COVID['SYMPTOMS'] = df_COVID[['SYMPTOM1', 'SYMPTOM2', 'SYMPTOM3', 'SYMPTOM4', 'SYMPTOM5']].fillna('').apply(lambda x: ' '.join(x), axis=1)
df_COVID.SYMPTOMS = [w.lower() for w in df_COVID.SYMPTOMS]
df_COVID['SYMPTOMS'].fillna('', inplace=True)  
df_COVID['HOSPDAYS'].fillna(0.,inplace=True)

# %%
print(df_COVID.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 910791 entries, 0 to 910790
# Data columns (total 54 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAERS_ID         910791 non-null  int64
#  1   RECVDATE         910791 non-null  object
#  2   STATE            910791 non-null  object
#  3   AGE_YRS          910791 non-null  float64
#  4   CAGE_YR          709781 non-null  float64
#  5   CAGE_MO          4258 non-null    float64
#  6   SEX              910791 non-null  object
#  7   RPT_DATE         902 non-null     object
#  8   SYMPTOM_TEXT     910791 non-null  object
#  9   DIED             17244 non-null   object
#  10  DATEDIED         15226 non-null   object
#  11  L_THREAT         14897 non-null   object
#  12  ER_VISIT         137 non-null     object
#  13  HOSPITAL         79771 non-null   object
#  14  HOSPDAYS         910791 non-null  float64
#  15  X_STAY           492 non-null     object
#  16  DISABLE          18058 non-null   object
#  17  RECOVD           829181 non-null  object
#  18  VAX_DATE         837843 non-null  object
#  19  ONSET_DATE       816422 non-null  object
#  20  NUMDAYS          778506 non-null  float64
#  21  LAB_DATA         313737 non-null  object
#  22  V_ADMINBY        910791 non-null  object
#  23  V_FUNDBY         973 non-null     object
#  24  OTHER_MEDS       454499 non-null  object
#  25  CUR_ILL          910791 non-null  object
#  26  HISTORY          910791 non-null  object
#  27  PRIOR_VAX        46534 non-null   object
#  28  SPLTTYPE         312288 non-null  object
#  29  FORM_VERS        910791 non-null  int64
#  30  TODAYS_DATE      903843 non-null  object
#  31  BIRTH_DEFECT     609 non-null     object
#  32  OFC_VISIT        191564 non-null  object
#  33  ER_ED_VISIT      114172 non-null  object
#  34  ALLERGIES        910791 non-null  object
#  35  SYMPTOM1         910791 non-null  object
#  36  SYMPTOMVERSION1  910791 non-null  float64
#  37  SYMPTOM2         743379 non-null  object
#  38  SYMPTOMVERSION2  743379 non-null  float64
#  39  SYMPTOM3         573924 non-null  object
#  40  SYMPTOMVERSION3  573924 non-null  float64
#  41  SYMPTOM4         432266 non-null  object
#  42  SYMPTOMVERSION4  432266 non-null  float64
#  43  SYMPTOM5         324771 non-null  object
#  44  SYMPTOMVERSION5  324771 non-null  float64
#  45  VAX_TYPE         632572 non-null  object
#  46  VAX_MANU         910791 non-null  object
#  47  VAX_LOT          910791 non-null  object
#  48  VAX_DOSE_SERIES  906594 non-null  object
#  49  VAX_ROUTE        687779 non-null  object
#  50  VAX_SITE         910791 non-null  object
#  51  VAX_NAME         910791 non-null  object
#  52  DAYS_to_DEATH    14905 non-null   float64
#  53  SYMPTOMS         910791 non-null  object
# dtypes: float64(11), int64(2), object(41)
# memory usage: 375.2+ MB
# None

# %%
def cleanup_text(df, text_col,clean_col="clean_text",stopwords=stopwords):
    stop_words = stopwords.words('english')
    df[clean_col] = df[text_col].copy() #copy original text to clean_text for cleaning
    df[clean_col] = [re.sub(r'[^\w\s]+','',w) for w in df[clean_col]]#cleanup punctuations
    df[clean_col] = [re.sub(r'[0-9]+','',w) for w in df[clean_col]]#cleanup numbers
    df[clean_col] = df[clean_col].apply(lambda w: ' '.join([word for word in w.split() if word not in (stop_words)])) #remove stopwords
    df[clean_col] = [re.sub(' +',' ',w) for w in df[clean_col]] #remove abnormal spacing
    return df

# %%
df_COVID_clean = cleanup_text(df_COVID,"SYMPTOMS","clean_text")

# %%
df_COVID = df_COVID_clean.drop("SYMPTOMS",axis=1).rename(columns={"clean_text":"SYMPTOMS"}) #make it our clean one

# %%
# Define features we might want to look at
categorical_features = ['SEX', 'STATE', 'VAX_LOT', 'VAX_MANU', 'VAX_SITE',"HOSPITAL"]
numerical_features = ['AGE_YRS',"HOSPDAYS"]
text_feature_allergies = 'ALLERGIES'
text_feature_HISTORY = 'HISTORY'
text_feature_CUR_ILL = "CUR_ILL"
text_feature_symptoms = 'SYMPTOMS'  




df_COVID['HOSPITAL'] = df_COVID['HOSPITAL'].apply(lambda x: 1 if pd.notnull(x) else 0)

df_COVID['DIED'] = df_COVID['DIED'].apply(lambda x: 1 if pd.notnull(x) else 0)

# %%
df_COVID[numerical_features+["DIED"]].corr().reset_index().melt('index')
# Out:
#       index  variable     value
# 0   AGE_YRS   AGE_YRS  1.000000
# 1  HOSPDAYS   AGE_YRS  0.003181
# 2      DIED   AGE_YRS  0.154165
# 3   AGE_YRS  HOSPDAYS  0.003181
# 4  HOSPDAYS  HOSPDAYS  1.000000
# 5      DIED  HOSPDAYS  0.002571
# 6   AGE_YRS      DIED  0.154165
# 7  HOSPDAYS      DIED  0.002571
# 8      DIED      DIED  1.000000

# %%
df_COVID[numerical_features+["DIED"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 910791 entries, 0 to 910790
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   AGE_YRS   910791 non-null  float64
#  1   HOSPDAYS  910791 non-null  float64
#  2   DIED      910791 non-null  int64
# dtypes: float64(2), int64(1)
# memory usage: 20.8 MB

# %%
df_COVID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 910791 entries, 0 to 910790
# Data columns (total 54 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAERS_ID         910791 non-null  int64
#  1   RECVDATE         910791 non-null  object
#  2   STATE            910791 non-null  object
#  3   AGE_YRS          910791 non-null  float64
#  4   CAGE_YR          709781 non-null  float64
#  5   CAGE_MO          4258 non-null    float64
#  6   SEX              910791 non-null  object
#  7   RPT_DATE         902 non-null     object
#  8   SYMPTOM_TEXT     910791 non-null  object
#  9   DIED             910791 non-null  int64
#  10  DATEDIED         15226 non-null   object
#  11  L_THREAT         14897 non-null   object
#  12  ER_VISIT         137 non-null     object
#  13  HOSPITAL         910791 non-null  int64
#  14  HOSPDAYS         910791 non-null  float64
#  15  X_STAY           492 non-null     object
#  16  DISABLE          18058 non-null   object
#  17  RECOVD           829181 non-null  object
#  18  VAX_DATE         837843 non-null  object
#  19  ONSET_DATE       816422 non-null  object
#  20  NUMDAYS          778506 non-null  float64
#  21  LAB_DATA         313737 non-null  object
#  22  V_ADMINBY        910791 non-null  object
#  23  V_FUNDBY         973 non-null     object
#  24  OTHER_MEDS       454499 non-null  object
#  25  CUR_ILL          910791 non-null  object
#  26  HISTORY          910791 non-null  object
#  27  PRIOR_VAX        46534 non-null   object
#  28  SPLTTYPE         312288 non-null  object
#  29  FORM_VERS        910791 non-null  int64
#  30  TODAYS_DATE      903843 non-null  object
#  31  BIRTH_DEFECT     609 non-null     object
#  32  OFC_VISIT        191564 non-null  object
#  33  ER_ED_VISIT      114172 non-null  object
#  34  ALLERGIES        910791 non-null  object
#  35  SYMPTOM1         910791 non-null  object
#  36  SYMPTOMVERSION1  910791 non-null  float64
#  37  SYMPTOM2         743379 non-null  object
#  38  SYMPTOMVERSION2  743379 non-null  float64
#  39  SYMPTOM3         573924 non-null  object
#  40  SYMPTOMVERSION3  573924 non-null  float64
#  41  SYMPTOM4         432266 non-null  object
#  42  SYMPTOMVERSION4  432266 non-null  float64
#  43  SYMPTOM5         324771 non-null  object
#  44  SYMPTOMVERSION5  324771 non-null  float64
#  45  VAX_TYPE         632572 non-null  object
#  46  VAX_MANU         910791 non-null  object
#  47  VAX_LOT          910791 non-null  object
#  48  VAX_DOSE_SERIES  906594 non-null  object
#  49  VAX_ROUTE        687779 non-null  object
#  50  VAX_SITE         910791 non-null  object
#  51  VAX_NAME         910791 non-null  object
#  52  DAYS_to_DEATH    14905 non-null   float64
#  53  SYMPTOMS         910791 non-null  object
# dtypes: float64(11), int64(4), object(39)
# memory usage: 375.2+ MB

# %% [markdown]
# We can visualize if any of the words are highly correlated with the patient dieing using TFID
#
# **SYMPTOMS**

# %%
KEYWORD = "SYMPTOMS"
df_COVID[KEYWORD] = df_COVID[KEYWORD].astype(str)
tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_features=100) 
tfidf_matrix = tfidf_vectorizer.fit_transform(df_COVID[KEYWORD])
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out())
tfidf_df['DIED'] = df_COVID['DIED'].copy()
correlation_matrix = tfidf_df.corr()
correlation_with_died = correlation_matrix['DIED'].drop('DIED').sort_values(ascending=False)
print(f"Top 20 postive correlated words from {KEYWORD}")
print(correlation_with_died.head(20))
print(f"Top 20 negative correlated words from {KEYWORD}")
print(correlation_with_died.tail(20))
correlation_data = correlation_with_died.reset_index()
correlation_data.columns = ['word', 'correlation']

heatmap = alt.Chart(correlation_data).mark_rect().encode(
    x=alt.X('word:N', title='Word', sort=None),
    y=alt.Y('correlation:Q', title='Correlation with DIED'),
    color=alt.Color('correlation:Q', scale=alt.Scale(scheme='redblue')),
    tooltip=[alt.Tooltip('word:N', title='Word'), alt.Tooltip('correlation:Q', title='Correlation')]
).properties(
    title=f'Correlation Between TF-IDF Words {KEYWORD} and Death (DIED)',
    width=2000,
    height=300
)

heatmap
# Out:
# Top 20 postive correlated words from SYMPTOMS
# death           0.801784
# acute           0.140926
# covid           0.116855
# cardiac         0.100493
# respiratory     0.098832
# failure         0.087554
# positive        0.054081
# dyspnoea        0.029131
# sarscov         0.023226
# xray            0.022863
# aggravated      0.017023
# condition       0.016886
# asthenia        0.015830
# abnormal        0.015058
# infection       0.013436
# tomogram        0.009753
# computerised    0.009746
# test            0.007862
# cough           0.005906
# blood           0.003156
# Name: DIED, dtype: float64
# Top 20 negative correlated words from SYMPTOMS
# feeling        -0.024535
# discomfort     -0.024825
# myalgia        -0.026459
# nausea         -0.027744
# arthralgia     -0.029388
# extremity      -0.030807
# pruritus       -0.031175
# rash           -0.031527
# pyrexia        -0.031878
# erythema       -0.032089
# swelling       -0.032319
# dizziness      -0.034976
# administered   -0.035834
# product        -0.037273
# injection      -0.040490
# chills         -0.040796
# fatigue        -0.041168
# site           -0.046657
# headache       -0.048185
# pain           -0.058918
# Name: DIED, dtype: float64
# alt.Chart(...)

# %% [markdown]
# That is a significant **leakage** word, *death*.  We will remove it later to prevent data leakage.

# %% [markdown]
# **HISTORY**

# %%
KEYWORD = "HISTORY"
df_COVID[KEYWORD] = df_COVID[KEYWORD].astype(str)
tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_features=100) 
tfidf_matrix = tfidf_vectorizer.fit_transform(df_COVID[KEYWORD])
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out())
tfidf_df['DIED'] = df_COVID['DIED'].copy()
correlation_matrix = tfidf_df.corr()
correlation_with_died = correlation_matrix['DIED'].drop('DIED').sort_values(ascending=False)
print(f"Top 20 postive correlated words from {KEYWORD}")
print(correlation_with_died.head(20))
print(f"Top 20 negative correlated words from {KEYWORD}")
print(correlation_with_died.tail(20))
correlation_data = correlation_with_died.reset_index()
correlation_data.columns = ['word', 'correlation']

heatmap = alt.Chart(correlation_data).mark_rect().encode(
    x=alt.X('word:N', title='Word', sort=None),
    y=alt.Y('correlation:Q', title='Correlation with DIED'),
    color=alt.Color('correlation:Q', scale=alt.Scale(scheme='redblue')),
    tooltip=[alt.Tooltip('word:N', title='Word'), alt.Tooltip('correlation:Q', title='Correlation')]
).properties(
    title=f'Correlation Between TF-IDF Words {KEYWORD} and Death (DIED)',
    width=2000,
    height=300
)

heatmap
# Out:
# Top 20 postive correlated words from HISTORY
# failure           0.091570
# htn               0.078724
# cad               0.073180
# copd              0.067407
# stage             0.060421
# dm                0.053836
# fibrillation      0.051160
# hyperlipidemia    0.045558
# atrial            0.045485
# artery            0.043895
# disease           0.043422
# coronary          0.041837
# mellitus          0.040119
# chronic           0.039813
# pulmonary         0.038694
# kidney            0.036596
# lung              0.036535
# heart             0.036499
# acute             0.035756
# unspecified       0.034841
# Name: DIED, dtype: float64
# Top 20 negative correlated words from HISTORY
# seasonal      -0.009162
# penicillin    -0.009682
# cholesterol   -0.009744
# provided      -0.010197
# reporter      -0.010244
# blood         -0.010614
# pressure      -0.010659
# comments      -0.012057
# migraines     -0.012117
# list          -0.012750
# high          -0.013140
# encoded       -0.014287
# relevant      -0.014685
# allergies     -0.016556
# allergy       -0.018983
# asthma        -0.020124
# history       -0.023760
# conditions    -0.026820
# concurrent    -0.028938
# medical       -0.029460
# Name: DIED, dtype: float64
# alt.Chart(...)

# %% [markdown]
# **CUR_ILL**

# %%
KEYWORD = "CUR_ILL"
df_COVID[KEYWORD] = df_COVID[KEYWORD].astype(str)
tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_features=100) 
tfidf_matrix = tfidf_vectorizer.fit_transform(df_COVID[KEYWORD])
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out())
tfidf_df['DIED'] = df_COVID['DIED'].copy()
correlation_matrix = tfidf_df.corr()
correlation_with_died = correlation_matrix['DIED'].drop('DIED').sort_values(ascending=False)
print(f"Top 20 postive correlated words from {KEYWORD}")
print(correlation_with_died.head(20))
print(f"Top 20 negative correlated words from {KEYWORD}")
print(correlation_with_died.tail(20))
correlation_data = correlation_with_died.reset_index()
correlation_data.columns = ['word', 'correlation']

heatmap = alt.Chart(correlation_data).mark_rect().encode(
    x=alt.X('word:N', title='Word', sort=None),
    y=alt.Y('correlation:Q', title='Correlation with DIED'),
    color=alt.Color('correlation:Q', scale=alt.Scale(scheme='redblue')),
    tooltip=[alt.Tooltip('word:N', title='Word'), alt.Tooltip('correlation:Q', title='Correlation')]
).properties(
    title=f'Correlation Between TF-IDF Words {KEYWORD} and Death (DIED)',
    width=2000,
    height=300
)

heatmap
# Out:
# Top 20 postive correlated words from CUR_ILL
# failure           0.055522
# unknown           0.046462
# acute             0.027771
# copd              0.026432
# htn               0.023271
# heart             0.022184
# chronic           0.021401
# hyperlipidemia    0.019530
# anemia            0.016397
# 21                0.016300
# kidney            0.016267
# disease           0.015299
# uti               0.013749
# 19                0.013511
# type              0.013202
# diabetes          0.012870
# cancer            0.012790
# unspecified       0.012514
# hypertension      0.011930
# 2021              0.011821
# Name: DIED, dtype: float64
# Top 20 negative correlated words from CUR_ILL
# arthritis      -0.003038
# alcohol        -0.003272
# years          -0.003547
# allergic       -0.003739
# fibromyalgia   -0.003889
# verbatim       -0.003979
# cholesterol    -0.003984
# migraine       -0.004095
# abstains       -0.004148
# na             -0.004320
# penicillin     -0.004353
# denies         -0.004615
# sinus          -0.005068
# asthma         -0.005069
# reaction       -0.005268
# seasonal       -0.005770
# cold           -0.005778
# drug           -0.006463
# allergies      -0.007123
# allergy        -0.012007
# Name: DIED, dtype: float64
# alt.Chart(...)

# %% [markdown]
# **ALLERGIES**

# %%
KEYWORD = "ALLERGIES"
df_COVID[KEYWORD] = df_COVID[KEYWORD].astype(str)
tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_features=100) 
tfidf_matrix = tfidf_vectorizer.fit_transform(df_COVID[KEYWORD])
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out())
tfidf_df['DIED'] = df_COVID['DIED'].copy()
correlation_matrix = tfidf_df.corr()
correlation_with_died = correlation_matrix['DIED'].drop('DIED').sort_values(ascending=False)
print(f"Top 20 postive correlated words from {KEYWORD}")
print(correlation_with_died.head(20))
print(f"Top 20 negative correlated words from {KEYWORD}")
print(correlation_with_died.tail(20))
correlation_data = correlation_with_died.reset_index()
correlation_data.columns = ['word', 'correlation']

heatmap = alt.Chart(correlation_data).mark_rect().encode(
    x=alt.X('word:N', title='Word', sort=None),
    y=alt.Y('correlation:Q', title='Correlation with DIED'),
    color=alt.Color('correlation:Q', scale=alt.Scale(scheme='redblue')),
    tooltip=[alt.Tooltip('word:N', title='Word'), alt.Tooltip('correlation:Q', title='Correlation')]
).properties(
    title=f'Correlation Between TF-IDF Words {KEYWORD} and Death (DIED)',
    width=2000,
    height=300
)

heatmap
# Out:
# Top 20 postive correlated words from ALLERGIES
# unknown        0.050929
# penicillins    0.017033
# known          0.014771
# nkda           0.014419
# nka            0.014084
# lisinopril     0.011092
# allergies      0.010466
# reaction       0.008065
# reported       0.006995
# oxycodone      0.006622
# nausea         0.005335
# swelling       0.004784
# cephalexin     0.004664
# itching        0.003392
# vomiting       0.003227
# tramadol       0.003173
# codeine        0.002976
# drug           0.002706
# rash           0.002389
# adhesive       0.002084
# Name: DIED, dtype: float64
# Top 20 negative correlated words from ALLERGIES
# peanuts       -0.005591
# wheat         -0.005973
# cats          -0.006095
# sensitivity   -0.006320
# pollen        -0.006436
# dust          -0.006604
# nuts          -0.006723
# tree          -0.006788
# mold          -0.007062
# dairy         -0.007530
# shellfish     -0.007712
# seasonal      -0.008203
# amoxicillin   -0.008476
# drugs         -0.008746
# gluten        -0.009182
# allergic      -0.009233
# allergy       -0.009285
# latex         -0.009570
# penicillin    -0.011850
# sulfa         -0.013034
# Name: DIED, dtype: float64
# alt.Chart(...)

# %%
KEYWORD = "SYMPTOM_TEXT"
df_COVID[KEYWORD] = df_COVID[KEYWORD].astype(str)
tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_features=100) 
tfidf_matrix = tfidf_vectorizer.fit_transform(df_COVID[KEYWORD])
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out())
tfidf_df['DIED'] = df_COVID['DIED'].copy()
correlation_matrix = tfidf_df.corr()
correlation_with_died = correlation_matrix['DIED'].drop('DIED').sort_values(ascending=False)
print(f"Top 20 postive correlated words from {KEYWORD}")
print(correlation_with_died.head(20))
print(f"Top 20 negative correlated words from {KEYWORD}")
print(correlation_with_died.tail(20))
correlation_data = correlation_with_died.reset_index()
correlation_data.columns = ['word', 'correlation']

heatmap = alt.Chart(correlation_data).mark_rect().encode(
    x=alt.X('word:N', title='Word', sort=None),
    y=alt.Y('correlation:Q', title='Correlation with DIED'),
    color=alt.Color('correlation:Q', scale=alt.Scale(scheme='redblue')),
    tooltip=[alt.Tooltip('word:N', title='Word'), alt.Tooltip('correlation:Q', title='Correlation')]
).properties(
    title=f'Correlation Between TF-IDF Words {KEYWORD} and Death (DIED)',
    width=2000,
    height=300
)

heatmap
# Out:
# Top 20 postive correlated words from SYMPTOM_TEXT
# positive       0.099745
# covid          0.099335
# 21             0.097907
# 2021           0.088186
# patient        0.044969
# 2022           0.044568
# 12             0.036367
# 10             0.028637
# medical        0.024266
# 19             0.021304
# event          0.013414
# prior          0.011748
# case           0.011662
# reported       0.008590
# date           0.005771
# blood          0.005705
# unspecified    0.002359
# 30             0.001998
# time           0.001036
# pfizer        -0.001089
# Name: DIED, dtype: float64
# Top 20 negative correlated words from SYMPTOM_TEXT
# dosage        -0.032351
# sore          -0.032480
# dose          -0.032988
# experienced   -0.033309
# rash          -0.033761
# left          -0.034168
# included      -0.034440
# 1273          -0.034684
# describes     -0.035276
# occurrence    -0.035415
# body          -0.035700
# chills        -0.037103
# concomitant   -0.037397
# mrna          -0.038153
# outcome       -0.039827
# pain          -0.042031
# site          -0.042750
# headache      -0.045081
# injection     -0.047095
# arm           -0.056367
# Name: DIED, dtype: float64
# alt.Chart(...)

# %%
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
label_encoder = LabelEncoder()

df_COVID['VAX_LOT_encoded'] = label_encoder.fit_transform(df_COVID['VAX_LOT'])
df_COVID['SEX_encoded'] = label_encoder.fit_transform(df_COVID['SEX'])
correlation_matrix = df_COVID[['VAX_LOT_encoded', 'SEX_encoded','DIED']].corr()

print(correlation_matrix)

corr_matrix = correlation_matrix
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap - Categorical Features', fontsize=16)
plt.show()
# Out:
#                  VAX_LOT_encoded  SEX_encoded      DIED
# VAX_LOT_encoded         1.000000     0.073659 -0.018087
# SEX_encoded             0.073659     1.000000  0.065482
# DIED                   -0.018087     0.065482  1.000000

# %% [markdown]
# * Look for data leakage by keywords in the **SYMPTOMS** that might indicate they died like *death*.

# %%
df_COVID[(df_COVID.SYMPTOMS.str.contains("death")) & (df_COVID.DIED==1)] #Does include 'death'
# Out:
#         VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 5083      910363  12/28/2020    CA     84.0     84.0      NaN   M      NaN
# 7214      913143  12/29/2020    TX     84.0     84.0      NaN   F      NaN
# 7697      913733  12/30/2020    PA     85.0     85.0      NaN   F      NaN
# 8436      914604  12/30/2020    MI     74.0     74.0      NaN   M      NaN
# 8450      914621  12/30/2020    IA     89.0     89.0      NaN   F      NaN
# ...          ...         ...   ...      ...      ...      ...  ..      ...
# 910579   2785362  08/19/2024    MO     68.0     68.0      NaN   F      NaN
# 910598   2785541  08/20/2024    MS     82.0     82.0      NaN   M      NaN
# 910651   2786159  08/22/2024    MN     65.0     65.0      NaN   F      NaN
# 910661   2786281  08/22/2024    TX     81.0      NaN      NaN   F      NaN
# 910700   2786719  08/26/2024    MN     44.0     44.0      NaN   M      NaN
#
#                                              SYMPTOM_TEXT  DIED  ...  \
# 5083    Patient had mild hypotension, decreased oral i...     1  ...
# 7214    Vaccine administered with no immediate adverse...     1  ...
# 7697    My grandmother died a few hours after receivin...     1  ...
# 8436    Spouse awoke 12/20 and found spouse dead. Clie...     1  ...
# 8450    Resident in our long term care facility who re...     1  ...
# ...                                                   ...   ...  ...
# 910579  Turbo Cancer rapidly spread throughout her bod...     1  ...
# 910598  Reported Symptoms: 10011906:DEATH;  Narrative:...     1  ...
# 910651                         Patient expired 8/21/2024.     1  ...
# 910661  death; shortness of breath; Nausea; vomiting; ...     1  ...
# 910700                      Patient expired on 8/25/2024.     1  ...
#
#                VAX_MANU      VAX_LOT VAX_DOSE_SERIES  VAX_ROUTE  VAX_SITE  \
# 5083            MODERNA  LOT 039K20A               1         IM        RA
# 7214    PFIZER\BIONTECH       EL0140               1         IM        LA
# 7697            Unknown      Unknown             UNK        NaN   Unknown
# 8436    PFIZER\BIONTECH       EH9899               1         IM   Unknown
# 8450            MODERNA      011J02A               1         IM        RA
# ...                 ...          ...             ...        ...       ...
# 910579          MODERNA      033F21A               3        SYR        RA
# 910598          MODERNA      039K20A               1         IM        RA
# 910651          MODERNA      031A21A               1         IM        LA
# 910661          Unknown      Unknown               1        NaN        RA
# 910700  PFIZER\BIONTECH       EW0151               1         IM        LA
#
#                                    VAX_NAME DAYS_to_DEATH  \
# 5083            COVID19 (COVID19 (MODERNA))           5.0
# 7214    COVID19 (COVID19 (PFIZER-BIONTECH))           0.0
# 7697            COVID19 (COVID19 (MODERNA))           0.0
# 8436    COVID19 (COVID19 (PFIZER-BIONTECH))           4.0
# 8450            COVID19 (COVID19 (MODERNA))           5.0
# ...                                     ...           ...
# 910579          COVID19 (COVID19 (MODERNA))         945.0
# 910598          COVID19 (COVID19 (MODERNA))          10.0
# 910651          COVID19 (COVID19 (MODERNA))         138.0
# 910661  COVID19 (COVID19 (PFIZER-BIONTECH))           NaN
# 910700  COVID19 (COVID19 (PFIZER-BIONTECH))         208.0
#
#                                                  SYMPTOMS VAX_LOT_encoded  \
# 5083              death hypophagia hypotension somnolence           33560
# 7214                                                death           24333
# 7697                                                death           36872
# 8436                                                death           23745
# 8450                               death dementia fatigue            3010
# ...                                                   ...             ...
# 910579  death metastases central nervous system metast...            9278
# 910598  cardiac failure congestive confusional state d...           10425
# 910651                                              death            8546
# 910661                     death dyspnoea nausea vomiting           36872
# 910700                                              death           27307
#
#        SEX_encoded
# 5083             1
# 7214             0
# 7697             0
# 8436             1
# 8450             0
# ...            ...
# 910579           0
# 910598           1
# 910651           0
# 910661           0
# 910700           1
#
# [12529 rows x 56 columns]

# %%
list(df_COVID[(df_COVID.SYMPTOMS.str.lower().str.contains("death")) & (df_COVID.DIED==1)].SYMPTOMS)[0:20]
# Out:
# ['death hypophagia hypotension somnolence',
#  'death',
#  'death',
#  'death',
#  'death dementia fatigue',
#  'anxiety death pyrexia respiratory distress sarscov test negative',
#  'death',
#  'death',
#  'death myocardial infarction',
#  'death',
#  'death',
#  'death dyspnoea vomiting',
#  'cardiac arrest death unresponsive stimuli',
#  'death',
#  'death',
#  'covid death sarscov test positive',
#  'covid death exposure sarscov sarscov test positive',
#  'covid death sarscov test positive',
#  'death unresponsive stimuli',
#  'death pulse absent respiratory arrest resuscitation unresponsive stimuli']

# %%
df_COVID[(~df_COVID.SYMPTOMS.str.contains("death")) & (df_COVID.DIED==1)] #Does NOT include 'death'
# Out:
#         VAERS_ID    RECVDATE    STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 4110      909095  12/25/2020       CO     66.0     66.0      NaN   M      NaN
# 11660     918418  01/04/2021       FL     65.0     65.0      NaN   M      NaN
# 12170     919108  01/04/2021       NY    100.0    100.0      NaN   F      NaN
# 12528     919537  01/04/2021       MN     96.0     96.0      NaN   F      NaN
# 13212     920368  01/05/2021       IN     92.0     92.0      NaN   F      NaN
# ...          ...         ...      ...      ...      ...      ...  ..      ...
# 910153   2781549  07/26/2024       FL     91.0     91.0      NaN   M      NaN
# 910198   2781731  07/29/2024       GA     78.0     78.0      NaN   F      NaN
# 910276   2782225  07/31/2024       TN     77.0     77.0      NaN   M      NaN
# 910297   2782378  08/01/2024       MI     55.0     55.0      NaN   M      NaN
# 910624   2785730  08/20/2024  Unknown     51.0      NaN      NaN   M      NaN
#
#                                              SYMPTOM_TEXT  DIED  ...  \
# 4110    on 12/24/2020 the resident was sleepy and stay...     1  ...
# 11660   Resident became SOB, congested and hypoxic req...     1  ...
# 12170                                      Fever, Malaise     1  ...
# 12528   Resident exhibited no adverse events during 30...     1  ...
# 13212   12/30/2020 07:02 AM  Resident noted to have so...     1  ...
# ...                                                   ...   ...  ...
# 910153  Reported Symptoms:  10011906:DEATH;  10057678:...     1  ...
# 910198  Resident had a heart attack in the dining room...     1  ...
# 910276                    Covid-19 breakthrough infection     1  ...
# 910297                                        Lung Cancer     1  ...
# 910624  positive for SARS-CoV-2; positive for SARS-CoV...     1  ...
#
#                VAX_MANU    VAX_LOT VAX_DOSE_SERIES  VAX_ROUTE  VAX_SITE  \
# 4110            MODERNA    011J20A               1         IM        RA
# 11660   PFIZER\BIONTECH     EL0140               1         IM        RA
# 12170   PFIZER\BIONTECH     F10140             UNK         IM   Unknown
# 12528           MODERNA    026L20A               1         IM        RA
# 13212           MODERNA    026L20A               1         IM        RA
# ...                 ...        ...             ...        ...       ...
# 910153          MODERNA    065F21A               3         IM        RA
# 910198          MODERNA  206E23-2A               6         IM        LA
# 910276          MODERNA    004M20A               2        NaN   Unknown
# 910297          Unknown    Unknown               1        NaN   Unknown
# 910624          Unknown    Unknown               1        NaN   Unknown
#
#                                     VAX_NAME DAYS_to_DEATH  \
# 4110             COVID19 (COVID19 (MODERNA))           2.0
# 11660    COVID19 (COVID19 (PFIZER-BIONTECH))           4.0
# 12170    COVID19 (COVID19 (PFIZER-BIONTECH))          12.0
# 12528            COVID19 (COVID19 (MODERNA))           0.0
# 13212            COVID19 (COVID19 (MODERNA))           3.0
# ...                                      ...           ...
# 910153  COVID19 (COVID19 (MODERNA BIVALENT))           0.0
# 910198           COVID19 (COVID19 (MODERNA))           4.0
# 910276           COVID19 (COVID19 (MODERNA))         833.0
# 910297           COVID19 (COVID19 (MODERNA))        1139.0
# 910624   COVID19 (COVID19 (PFIZER-BIONTECH))           NaN
#
#                                                  SYMPTOMS VAX_LOT_encoded  \
# 4110    foaming mouth pain extremity pallor pulse abse...            3031
# 11660   dyspnoea hospice care hypoxia oxygen saturatio...           24333
# 12170   blood culture culture urine full blood count m...           29032
# 12528                                        pulse absent            6862
# 13212   blood creatinine increased blood urea increase...            6862
# ...                                                   ...             ...
# 910153             disease complication vascular dementia           13903
# 910198             myocardial infarction posture abnormal           17263
# 910276                                 breakthrough covid            1458
# 910297                     biopsy lung neoplasm malignant           36872
# 910624  body temperature covid computerised tomogram i...           36872
#
#        SEX_encoded
# 4110             1
# 11660            1
# 12170            0
# 12528            0
# 13212            0
# ...            ...
# 910153           1
# 910198           0
# 910276           1
# 910297           1
# 910624           1
#
# [4715 rows x 56 columns]

# %%
list(df_COVID[(~df_COVID.SYMPTOMS.str.lower().str.contains("death")) & (df_COVID.DIED==1)].SYMPTOMS)[0:20]
# Out:
# ['foaming mouth pain extremity pallor pulse absent respiratory arrest',
#  'dyspnoea hospice care hypoxia oxygen saturation decreased pulse absent',
#  'blood culture culture urine full blood count malaise pyrexia',
#  'pulse absent',
#  'blood creatinine increased blood urea increased body temperature increased chest xray abnormal decreased appetite',
#  'abnormal behaviour blood pressure abnormal fatigue limb discomfort pulse absent',
#  'body temperature increased dyspnoea',
#  'pyrexia respiratory depression sarscov test positive',
#  'pupil fixed regurgitation respiratory arrest sarscov test positive unresponsive stimuli',
#  'cardiac arrest condition aggravated haemoptysis lung neoplasm malignant',
#  'chest pain dyspnoea myocardial infarction pyrexia',
#  'myocardial infarction',
#  'palpitations syncope',
#  'asymptomatic covid sarscov test positive',
#  'body temperature increased complication associated device cough dyspnoea hypoxia',
#  'cardiac arrest cardiac disorder intensive care withdrawal life support',
#  'heart rate increased musculoskeletal stiffness oxygen saturation decreased peripheral coldness presyncope',
#  'unresponsive stimuli',
#  'unresponsive stimuli',
#  'sarscov test positive']

# %%
list(df_COVID[df_COVID.SYMPTOMS.str.contains("autopsy")].SYMPTOMS)[0:20] #Another leaky word, 'autopsy'
# Out:
# ['autopsy cardiorespiratory arrest death resuscitation syncope',
#  'autopsy death',
#  'autopsy blood test culture tissue specimen death toxicologic test',
#  'autopsy cardiac arrest death pulse absent respiratory arrest',
#  'autopsy death syncope',
#  'autopsy death maternal exposure breast feeding',
#  'autopsy sudden death',
#  'autopsy death malaise',
#  'alanine aminotransferase normal aspartate aminotransferase increased autopsy bilirubin conjugated increased blood alkaline phosphatase increased',
#  'asthenia autopsy cardiac arrest death fatigue',
#  'autopsy cardiac arrest cardiorespiratory arrest chest xray abnormal cyanosis',
#  'autopsy cyanosis death dental discomfort diarrhoea haemorrhagic',
#  'autopsy cardiorespiratory arrest death',
#  'autopsy death',
#  'autopsy death',
#  'autopsy bone fragmentation computerised tomogram abnormal computerised tomogram spine death',
#  'autopsy death',
#  'autopsy coronary artery thrombosis sudden cardiac death',
#  'arteriosclerosis autopsy condition aggravated death',
#  'appetite disorder autopsy death migraine']

# %% [markdown]
# * We will cleanup the data some more so that we don't leak the truth into the training features.  We will remove rows with SYMPTOMS containing 'death' and 'autopsy'.

# %%
df_COVID = df_COVID[(~df_COVID.SYMPTOMS.str.contains("death")) & (~df_COVID.SYMPTOMS.str.contains("autopsy"))].reset_index().drop("index",axis=1)
df_COVID
# Out:
#         VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0         902418  12/15/2020    NJ     56.0     56.0      NaN   F      NaN
# 1         902440  12/15/2020    AZ     35.0     35.0      NaN   F      NaN
# 2         902446  12/15/2020    WV     55.0     55.0      NaN   F      NaN
# 3         902464  12/15/2020    LA     42.0     42.0      NaN   M      NaN
# 4         902465  12/15/2020    AR     60.0     60.0      NaN   F      NaN
# ...          ...         ...   ...      ...      ...      ...  ..      ...
# 897838   2787640  08/29/2024    NM     11.0     11.0      NaN   F      NaN
# 897839   2787643  08/29/2024    OR     67.0     67.0      NaN   F      NaN
# 897840   2787649  08/29/2024    FL     78.0     78.0      NaN   F      NaN
# 897841   2787667  08/29/2024    AZ     21.0     21.0      NaN   M      NaN
# 897842   2787668  08/30/2024    IN     37.0     37.0      NaN   F      NaN
#
#                                              SYMPTOM_TEXT  DIED  ...  \
# 0       Patient experienced mild numbness traveling fr...     0  ...
# 1                                            C/O Headache     0  ...
# 2       felt warm, hot and face and ears were red and ...     0  ...
# 3       within 15 minutes progressive light-headedness...     0  ...
# 4       Pt felt wave come over body @ 1218 starting in...     0  ...
# ...                                                   ...   ...  ...
# 897838  Moderna COVID vaccine for patients greater tha...     0  ...
# 897839  Dizziness immediately after vaccine lasting ab...     0  ...
# 897840  During a vaccine clinic at her nursing home, t...     0  ...
# 897841  Sickness for over a week including nausea and ...     0  ...
# 897842  Skin reactions, allergies, muscle weakness, bo...     0  ...
#
#                VAX_MANU  VAX_LOT VAX_DOSE_SERIES  VAX_ROUTE  VAX_SITE  \
# 0       PFIZER\BIONTECH   EH9899               1         IM        LA
# 1       PFIZER\BIONTECH  EH 9899               1        SYR        LA
# 2       PFIZER\BIONTECH   EH9899               1         IM        RA
# 3       PFIZER\BIONTECH   EH9899             UNK         IM        LA
# 4       PFIZER\BIONTECH   EH9899               1         IM        RA
# ...                 ...      ...             ...        ...       ...
# 897838          MODERNA  8062120               5         IM        LA
# 897839  PFIZER\BIONTECH   LM2216               1         IM        LA
# 897840          MODERNA  3042914             UNK         IM        RA
# 897841          MODERNA  038C21A               1        NaN        RA
# 897842  PFIZER\BIONTECH   Ew0153               1         IM        LA
#
#                                     VAX_NAME DAYS_to_DEATH  \
# 0        COVID19 (COVID19 (PFIZER-BIONTECH))           NaN
# 1        COVID19 (COVID19 (PFIZER-BIONTECH))           NaN
# 2        COVID19 (COVID19 (PFIZER-BIONTECH))           NaN
# 3        COVID19 (COVID19 (PFIZER-BIONTECH))           NaN
# 4        COVID19 (COVID19 (PFIZER-BIONTECH))           NaN
# ...                                      ...           ...
# 897838  COVID19 (COVID19 (MODERNA BIVALENT))           NaN
# 897839   COVID19 (COVID19 (PFIZER-BIONTECH))           NaN
# 897840  COVID19 (COVID19 (MODERNA BIVALENT))           NaN
# 897841           COVID19 (COVID19 (MODERNA))           NaN
# 897842   COVID19 (COVID19 (PFIZER-BIONTECH))           NaN
#
#                                                  SYMPTOMS VAX_LOT_encoded  \
# 0              hypoaesthesia injection site hypoaesthesia           23745
# 1                                                headache           23669
# 2                           erythema feeling hot flushing           23745
# 3       dizziness electrocardiogram normal hyperhidros...           23745
# 4       dysgeusia oral pruritus paraesthesia paraesthe...           23745
# ...                                                   ...             ...
# 897838     product administered patient inappropriate age           20544
# 897839                                   dizziness tremor           33522
# 897840       dyspepsia feeling abnormal throat irritation           18571
# 897841                            illness nausea vomiting           10118
# 897842  acrochordon alopecia anal fissure anxiety arth...           28812
#
#        SEX_encoded
# 0                0
# 1                0
# 2                0
# 3                1
# 4                0
# ...            ...
# 897838           0
# 897839           0
# 897840           0
# 897841           1
# 897842           0
#
# [897843 rows x 56 columns]

# %% [markdown]
# ## 1.4 Key-Insights

# %% [markdown]
# * It appears that a good chunk of the symptoms contain the word 'covid', which indicates a lot of these people who received the vaccine still got 'covid'.

# %%
print(len(list(df_COVID[df_COVID.SYMPTOMS.str.contains("covid")].SYMPTOMS)))
# Out:
# 80871

# %%
list(df_COVID[df_COVID.SYMPTOMS.str.contains("covid")].SYMPTOMS)[0:20]
# Out:
# ['ageusia anosmia body temperature increased covid chills',
#  'covid dyspnoea hospice care pyrexia sarscov test positive',
#  'covid decreased appetite fatigue headache myalgia',
#  'covid cough headache hyperhidrosis oropharyngeal pain',
#  'arthralgia blood test normal body temperature increased bradycardia covid pneumonia',
#  'covid lip swelling paraesthesia oral pruritus',
#  'covid chest xray abnormal exposure sarscov pneumonia',
#  'covid chills laboratory test pain pneumonia',
#  'arthralgia covid dizziness loss consciousness occupational exposure sarscov',
#  'covid impaired work ability pain extremity pyrexia sarscov test positive',
#  'covid sarscov test positive',
#  'covid sarscov test positive',
#  'asymptomatic covid sarscov test positive',
#  'covid nasal discomfort oropharyngeal pain sarscov test throat irritation',
#  'covid sarscov test positive unevaluable event',
#  'covid sarscov test positive',
#  'anosmia covid cough fatigue malaise',
#  'covid',
#  'covid fatigue nasal congestion pain sarscov test positive',
#  'covid sarscov test positive']

# %% [markdown]
# In fact, it appears that a significant amount of them even died with COVID.

# %%
print(len(list(df_COVID[(df_COVID.SYMPTOMS.str.contains("covid")) & (df_COVID.DIED==1)].SYMPTOMS)))
# Out:
# 1912

# %%
list(df_COVID[(df_COVID.SYMPTOMS.str.contains("covid")) & (df_COVID.DIED==1)].SYMPTOMS)[0:20]
# Out:
# ['asymptomatic covid sarscov test positive',
#  'asymptomatic covid',
#  'angiogram pulmonary abnormal covid pneumonia cardiomyopathy cardioversion central venous catheterisation',
#  'covid decreased appetite dyspnoea fluid intake reduced hypophagia',
#  'covid full blood count hyponatraemia metabolic function test',
#  'acute kidney injury acute myocardial infarction acute respiratory distress syndrome covid pneumonia cardiac failure acute',
#  'acute respiratory failure ageusia anosmia asthenia covid pneumonia',
#  'blood albumin decreased blood creatinine increased blood thyroid stimulating hormone normal blood urea increased covid',
#  'covid condition aggravated general physical health deterioration lethargy sarscov test positive',
#  'asthenia covid dyspnoea nausea sarscov test positive',
#  'blood pressure increased covid heart rate increased renal failure sarscov test positive',
#  'covid sarscov test positive',
#  'covid drug ineffective respiratory failure respiratory failure sarscov test',
#  'abdominal pain asthenia blood creatinine increased covid decreased appetite',
#  'covid myocardial infarction pulse absent respiratory arrest sarscov test positive',
#  'blood test covid pneumonia chest pain decreased appetite diarrhoea',
#  'covid sarscov test positive',
#  'angiogram abnormal brain natriuretic peptide covid immunisation computerised tomogram abnormal computerised tomogram head',
#  'covid coma sarscov test vascular dementia',
#  'body temperature increased covid covid pneumonia cough dyspnoea']

# %% [markdown]
# Of the people that died, there was still a good amount of them that died without COVID and was correlated with the vaccine.

# %%
print(len(list(df_COVID[(~df_COVID.SYMPTOMS.str.contains("covid")) & (df_COVID.DIED==1)].SYMPTOMS)))
# Out:
# 2729

# %%
list(df_COVID[(~df_COVID.SYMPTOMS.str.contains("covid")) & (df_COVID.DIED==1)].SYMPTOM_TEXT)[0:20]
# Out:
# ['on 12/24/2020 the resident was sleepy and stayed in bed most of the shift.  He stated he was doing okay but requested pain medication for his legs at 250PM.  At 255AM on 12/25/2020 the resident was observed in bed lying still, pale, eyes half open and foam coming from mouth and unresponsive.  He was not breathing and with no pulse',
#  'Resident became SOB, congested and hypoxic requiring oxygen, respiratory treatments and suctioning.  Stabilized after treatment and for the next 72 hours with oxygen saturations in the 90s.  On 1/3/2021 was found without pulse and respirations.  Resident was a DNR on Hospice.',
#  'Fever, Malaise',
#  'Resident exhibited no adverse events during 30 minute monitoring following vaccine administration. Resident found without pulse at 1900.',
#  '12/30/2020 07:02 AM  Resident noted to have some redness in face and respiration were fast. Resident vital signs were abnormal except blood pressure. Temp at the time was 102.0 F taken temporal. Resident respirations were 22 labored at times. Pulse is 105 and pulse ox 94% on room air. Resident is made comfortable in bed. Notified triage of change in condition also made triage aware of resident receiving Covid vaccination yesterday morning. Resident appetite and fluid consumption has been poor for few days.  12/30/2020 07:32 AM  Received order from agency to administer Acetaminophen 650mg suppos rectally due to resident not wanting to swallow anything including fluids, medications and food. This writer administered medication as NP ordered. Will monitor for effectiveness and adverse effects if any.  12/30/2020 08:41 AM  Received new orders to obtain Flu swab, obtain CBC and BMP, and Chest Xray all to be obtained today. Notified family of resident having temperature and vital signs excluding b/p that was abnormal. Family was thankful for call and inierated to nurse that family does not want resident sent to hospital. Did educate family on benefits of Hospice services, but family persistant on continued daily care provided by nursing staff. Requests visits if decline continues. Family assured if resident continues to decline, facility will accomandate resident family to be able to be at bedside when time comes to do so.  NP ordered IVF and IV Levaquin on 12/31/20. Family chose at that time to sign for Hospice services and not have resident provided with IVF or IV Antibiotics',
#  'The resident received is vaccine around 11:00 am and tolerated it without any difficulty or immediate adverse effects. He was at therapy from 12:36 pm until 1:22 pm when he stated he was too tired and could not do anymore. The therapist took him back to his room at that time and he got into bed himself but stated his legs felt heavy. At 1:50 pm the CNA answered his call light and found he had taken himself to the bathroom. She stated that when he went to get back into the bed it was "abnormal" how he was getting into it so she assisted him. At that time he quit breathing and she called a RN into the room immediately. He was found without a pulse, respirations, or blood pressure at 1:54 pm. He was a DNR.',
#  'Resident received Covid Vaccine, noted after 30 mins with labored breathing BP 161/77, HR 116, R 38, T 101.4,',
#  'Fever, RespDepression & COVID positive REMDESIVIR (EUA) 200 mg x1 then 100 mg daily',
#  "Patient did not display any obvious signs or symptoms; the vaccination was administered at approximately 10:00 AM and the patient continued throughout her day without any complaints or signs of adverse reaction. Patient was helped to bed by the nursing assistant estimated at around 9:00 PM. The facility received notification from the lab around 11:00 PM that the patient's COVID-19 specimen collection from Sunday, 1/3/21, detected COVID-19. When the nursing staff went to the room to check on the resident and prepare her to move to a COVID-19 care area the patient was found unresponsive,  no movement, no chest rises, noted regurgitated small amount of food to mouth left side, lying on left side. Pupils non reactive.",
#  'coughing up blood, significant hemoptysis -- > cardiac arrest. started day after vaccine but likely related to ongoing progression of lung cancer',
#  'Fever, shortness of breath and chest pain that resulted in a heart attack a few hours after vaccination',
#  'Medical docter state patient has a acute cardiac attack',
#  'Narrative: Symptoms: Palpitations & Syncope Treatment: EPINEPHRINE 1 MG ONCE ,EPINEPHRINE 1 MG ONCE ,SODIUM BICARBONATE 50 ML ONCE',
#  'hypoxia, secretions,cough, dyspnea Narrative: ALS patient on hospice with ongoing history of aspiration pna, receiving tube feeds. Developed incr in secretions, hypoxeia, temp and with recently noted clogged feeding tube.',
#  'The patient had an apparent cardiac arrest on 12/23/20 and was admitted to the ICU. He was taken off of life support on 12/30/20.  He had known cardiac disease.',
#  'Resident had seizure like activity followed by a vagel response with large bowel movement. Resident then began to show signs of blood clot to left lower extremity. No pedal pulse, area on leg warm to touch. Left lower leg now cold to touch, stiff, purple and white in color. No other signs of modeling, body warm to touch, no fever noted. Respirations and pulse increased with low oxygen levels. Resident not responding to stimuli.',
#  'Patient was found unresponsive at home with SpO2 20% 1/2/2021',
#  'RESIDENT 1ST DOSE OF MODERNA VACCINE ADMINISTERED ON 01/04/2021 AT 8:30PM, RESIDENT FOUND UNRESPONSIVE ON 01/05/2021.',
#  'The facility had positive cases for COVID 19 when the vaccine was received and administered to patient.  With her advanced age and chronic conditions, she did not have time to build immunity between the time of vaccination and her testing positive.',
#  'The facility had a number of positive COVID 19 cases prior to patients vaccination.  Due to her advanced age, chronic condition, and exposure, patient did not have the time to build immunity after exposure before becoming positive.']

# %% [markdown]
# # 2. Analysis - Model Building/Training

# %% [markdown]
# ## 2.1 Feature Selection/Engineering

# %% [markdown]
# We can use the numerical features, categorical features, and the other text based features we analyzed above to be part of our preprocessing step for training a model.
#
# Recall that we used Feature Engineering for our **SYMPTOMS** feature, where we combined SYMPTOMS1,2,3,4, and 5.

# %%
categorical_features = ['SEX', 'STATE','VAX_LOT', 'VAX_MANU', 'VAX_SITE', 'HOSPITAL']
numerical_features = ['AGE_YRS', 'HOSPDAYS']
text_features = ['ALLERGIES', 'HISTORY', 'CUR_ILL', 'SYMPTOMS']


tfidf_allergies = TfidfVectorizer(max_features=100, stop_words='english')
tfidf_history = TfidfVectorizer(max_features=100, stop_words='english')
tfidf_currill = TfidfVectorizer(max_features=100, stop_words='english')
tfidf_symptoms = TfidfVectorizer(max_features=100, stop_words='english')



preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),  
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features),  
        ('tfidf_allergies', tfidf_allergies, 'ALLERGIES'),  
        ('tfidf_history', tfidf_history, 'HISTORY'),
        ('tfidf_currill', tfidf_currill, 'CUR_ILL'),
        ('tfidf_symptoms', tfidf_symptoms, 'SYMPTOMS')
    ]
)

# %% [markdown]
# ## 2.2 Unsupervised Approach - NMF

# %% [markdown]
# * In order to use Non-Matrix Factorization (NMF), a unsupervised ML approach to predict the category from the text, we need to do an exhaustive search on the different permutations that our *n_components* could give us.  Therefore, we will make a *label_permute_score* and integrate it into a class we super from *sklearn* in order to train the model with *GridSearchCV*.
#
# * Also, we will do **hyperparameter** tuning based on the *l1_ratio*, *init*, *solver*, and *beta_loss* for NMF.  When exploring these hyperparameters with GridSearchCV we will use 3 kfolds to determine which parameters yield the best model.  We will then validate our models on the test set based on the given train/teset split.
#
# * We will use train/test splits with **test sizes** from *80 and 20% (train sizes of 20% and 80%)*.
#
# * We will also train a *Supervised ML* algorithm, **XGBoostClassifier**, to compare our **Unsupervised ML** approach with.

# %%
def label_permute_score(y_true, yp, n=3):
    perms = list(itertools.permutations(range(n)))# permutations
    best_acc = 0
    for perm in perms:
        perm_mapping = {i: perm[i] for i in range(n)}
        yp_mapped = [perm_mapping[label] for label in yp]
        current_accuracy = accuracy_score(y_true, yp_mapped)
        if current_accuracy > best_acc:
            best_acc = current_accuracy
    return best_acc

# %%
def label_permute_score_perm(y_true, yp, n=3):
    perms = list(itertools.permutations(range(n)))# permutations
    best_acc = 0
    best_perm = {i: perms[0][i] for i in range(n)}
    for perm in perms:
        perm_mapping = {i: perm[i] for i in range(n)}
        yp_mapped = [perm_mapping[label] for label in yp]
        current_accuracy = accuracy_score(y_true, yp_mapped)
        if current_accuracy > best_acc:
            best_acc = current_accuracy
            best_perm = perm_mapping
    return best_acc,best_perm #this also returns what our best permutation mapping was

# %%
class NMFClassifier(BaseEstimator, TransformerMixin): #these are imported from sklearn in order to use with GridSearchCV
    def __init__(self, n_components=5, l1_ratio=0.5,random_state=42,init="nndsvda",solver="mu",beta_loss="kullback-leibler"):
        self.n_components = n_components
        self.random_state = random_state
        self.l1_ratio = l1_ratio
        self.init = init
        self.solver = solver
        self.beta_loss = beta_loss
        self.nmf_model = NMF(n_components=self.n_components, l1_ratio=self.l1_ratio,random_state=self.random_state,
                             init=self.init,solver=self.solver,beta_loss=self.beta_loss)
    def fit(self, X, y=None):
        self.nmf_model = NMF(
        n_components=self.n_components, 
        l1_ratio=self.l1_ratio,
        random_state=self.random_state,
        init=self.init,
        solver=self.solver,
        beta_loss=self.beta_loss
        )
        # print("fitting",self.nmf_model.get_params())
        self.nmf_model.fit(X)
        return self
    
    def transform(self, X):
        X_nmf = self.nmf_model.transform(X)
        return X_nmf
    
    def predict(self, X):
        X_nmf = self.transform(X)
        return X_nmf.argmax(axis=1)
    
    def score(self, X, y):
        y_pred = self.predict(X)
        return label_permute_score(y, y_pred, n=self.n_components)

    def accuracy_score(self, X, y):
        y_pred = self.predict(X)
        return y_pred,label_permute_score(y, y_pred, n=self.n_components)

# %%
df_results = pd.DataFrame(columns=["Section","Model","test_size","f1_score_1","accuracy","random_state","description","balance_test","balance_train","gridsearch_model"])

# %%
mapping = {"LIVED":0,"DIED":1}
mapping
# Out:
# {'LIVED': 0, 'DIED': 1}

# %%
rev_mapping = {}
for k,v in mapping.items():
    rev_mapping[v] = k
rev_mapping
# Out:
# {0: 'LIVED', 1: 'DIED'}

# %%
df_COVID[["DIED","SYMPTOMS"]]
# Out:
#         DIED                                           SYMPTOMS
# 0          0         hypoaesthesia injection site hypoaesthesia
# 1          0                                           headache
# 2          0                      erythema feeling hot flushing
# 3          0  dizziness electrocardiogram normal hyperhidros...
# 4          0  dysgeusia oral pruritus paraesthesia paraesthe...
# ...      ...                                                ...
# 897838     0     product administered patient inappropriate age
# 897839     0                                   dizziness tremor
# 897840     0       dyspepsia feeling abnormal throat irritation
# 897841     0                            illness nausea vomiting
# 897842     0  acrochordon alopecia anal fissure anxiety arth...
#
# [897843 rows x 2 columns]

# %%
num_DEAD = len(df_COVID[df_COVID["DIED"]==1])
num_ALIVE = len(df_COVID[df_COVID["DIED"]!=1])
print("Number of people DEAD in df_COVID",num_DEAD)
print("Number of people AIVE in df_COVID",num_ALIVE)
# Out:
# Number of people DEAD in df_COVID 4641
# Number of people AIVE in df_COVID 893202

# %%
perc_dead = 100*(1-num_DEAD/(num_DEAD+num_ALIVE))
print("Perecent of people DEAD  in df_COVID",perc_dead)
# Out:
# Perecent of people DEAD  in df_COVID 99.48309448311119

# %% [markdown]
# * Imbalance Data obviously, so lets try **undersampling** as a strategy by training only on the same number total dead as alive, i.e. 17244

# %% [markdown]
# ### 2.2.1 Unsupervised ML - NMF - test_size = 0.8 - UNDERSAMPLE w. random_state = 42

# %%
Section = "2.2.1"
random_state = 42
test_size = 0.8
description = f"Unsupervised ML - NMF - test_size = {test_size} = UNDERSAMPLE w/ random_state = {random_state}"
df_COVID_dead = df_COVID[df_COVID["DIED"]==1]
df_COVID_alive = df_COVID[df_COVID["DIED"]!=1]
df_COVID_alive_sample = df_COVID_alive.sample(n=num_DEAD,random_state=random_state).reset_index().drop("index",axis=1) # UNDERSAMPLE
df = pd.concat([df_COVID_dead,df_COVID_alive_sample],axis=0).reset_index().drop("index",axis=1)
X = df[categorical_features + numerical_features + text_features]
y = df['DIED']  
print(len(df))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

n_components = len(df_COVID["DIED"].unique())
tfidvec = TfidfVectorizer(min_df=5,max_df=0.9,ngram_range=(1,2),tokenizer=word_tokenize,stop_words = 'english')
nmf_classifier = NMFClassifier(n_components=n_components)
preprocessor = ColumnTransformer(
    transformers=[
        ('tfidf', tfidvec, 'SYMPTOMS'),
    ]
)
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('nmf', nmf_classifier)
])
param_grid = {
    'nmf__l1_ratio': [0.5, 0.0],
    'nmf__solver': ['mu'],
    'nmf__beta_loss': ['frobenius', 'kullback-leibler'],
}
custom_scorer = make_scorer(lambda y_true, yp: label_permute_score(y_true, yp, n=n_components))
grid_search = GridSearchCV(pipeline, param_grid, scoring=custom_scorer, cv=3)
grid_search.fit(X_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best accuracy: {grid_search.best_score_:.2f}")
results = grid_search.cv_results_
print("Mean Test Scores for each parameter combination:")
for mean_score, params in zip(results['mean_test_score'], results['params']):
    print(f"{params}: {mean_score:.3f}")

print("Individual fold scores:")
print(results['split0_test_score'])
print(results['split1_test_score'])
print(results['split2_test_score'])

acc_i,mapping_i = label_permute_score_perm(y_train, grid_search.predict(X_train), n=n_components)
print(acc_i,mapping_i)

accuracy_score_i = grid_search.score(X_test,y_test)
y_pred = grid_search.predict(X_test)
y_pred = [mapping_i.get(w) for w in y_pred]
print("Accuracy:",accuracy_score_i)
print(classification_report(y_test,y_pred))

i =len(df_results)
df_results.at[i,"Model"] = "Unsupervised - NMF"
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
# Amount trained on y_train==1 i.e. DIED; shows the imbalance is not there, but still learned well
print(1-len(y_train[y_train==1])/len(y_train))
print(1-len(y_test[y_test==1])/len(y_test))
balance_train = 1-len(y_train[y_train==1])/len(y_train)
balance_test = 1-len(y_test[y_test==1])/len(y_test)
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# 9282
# Best parameters: {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}
# Best accuracy: 0.82
# Mean Test Scores for each parameter combination:
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.810
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.810
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.816
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.816
# Individual fold scores:
# [0.82875606 0.82875606 0.83521809 0.83521809]
# [0.80129241 0.80129241 0.80452342 0.80452342]
# [0.80097087 0.80097087 0.80906149 0.80906149]
# 0.8227370689655172 {0: 1, 1: 0}
# Accuracy: 0.8242660921088069
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83      3731
#            1       0.85      0.79      0.82      3695
#
#     accuracy                           0.82      7426
#    macro avg       0.83      0.82      0.82      7426
# weighted avg       0.83      0.82      0.82      7426
#
# 0.49030172413793105
# 0.502423915970913
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83      3731
#            1       0.85      0.79      0.82      3695
#
#     accuracy                           0.82      7426
#    macro avg       0.83      0.82      0.82      7426
# weighted avg       0.83      0.82      0.82      7426

# %% [markdown]
# ### 2.2.1.1 Supervised ML - XGBoostClassifier - test_size = 0.8 - UNDERSAMPLE w. random_state = 42

# %%
Section = "2.2.1.1"
description = "Supervised ML - XGBoost"
param_grid = {
    'classifier__learning_rate': [0.05, 0.1]
}
xgb_clf = xgb.XGBClassifier(random_state=random_state)
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', xgb_clf)
])

grid_search = GridSearchCV(model_pipeline, param_grid, cv=3, n_jobs=-1)
grid_search.fit(X_train, y_train)
print("Best parameters:", grid_search.best_params_)
y_pred = grid_search.predict(X_test)
accuracy_score_i =accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_score_i)
print(classification_report(y_test, y_pred))
i =len(df_results)
df_results.at[i,"Model"] = description
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# Best parameters: {'classifier__learning_rate': 0.1}
# Accuracy: 0.8490438998114732
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      3731
#            1       0.88      0.81      0.84      3695
#
#     accuracy                           0.85      7426
#    macro avg       0.85      0.85      0.85      7426
# weighted avg       0.85      0.85      0.85      7426
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      3731
#            1       0.88      0.81      0.84      3695
#
#     accuracy                           0.85      7426
#    macro avg       0.85      0.85      0.85      7426
# weighted avg       0.85      0.85      0.85      7426

# %% [markdown]
# ### 2.2.2 Unsupervised ML - NMF - test_size = 0.8 - UNDERSAMPLE w/ random_state = 43

# %%
Section = "2.2.2"
random_state = 43
test_size = 0.8
description = f"Unsupervised ML - NMF - test_size = {test_size} = UNDERSAMPLE w/ random_state = {random_state}"
df_COVID_dead = df_COVID[df_COVID["DIED"]==1]
df_COVID_alive = df_COVID[df_COVID["DIED"]!=1]
df_COVID_alive_sample = df_COVID_alive.sample(n=num_DEAD,random_state=random_state).reset_index().drop("index",axis=1) # UNDERSAMPLE
df = pd.concat([df_COVID_dead,df_COVID_alive_sample],axis=0).reset_index().drop("index",axis=1)
X = df[categorical_features + numerical_features + text_features]
y = df['DIED']  
print(len(df))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

n_components = len(df_COVID["DIED"].unique())
tfidvec = TfidfVectorizer(min_df=5,max_df=0.9,ngram_range=(1,2),tokenizer=word_tokenize,stop_words = 'english')
nmf_classifier = NMFClassifier(n_components=n_components)
preprocessor = ColumnTransformer(
    transformers=[
        ('tfidf', tfidvec, 'SYMPTOMS'),
    ]
)
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('nmf', nmf_classifier)
])
param_grid = {
    'nmf__l1_ratio': [0.5, 0.0],
    'nmf__solver': ['mu'],
    'nmf__beta_loss': ['frobenius', 'kullback-leibler'],
}
custom_scorer = make_scorer(lambda y_true, yp: label_permute_score(y_true, yp, n=n_components))
grid_search = GridSearchCV(pipeline, param_grid, scoring=custom_scorer, cv=3)
grid_search.fit(X_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best accuracy: {grid_search.best_score_:.2f}")
results = grid_search.cv_results_
print("Mean Test Scores for each parameter combination:")
for mean_score, params in zip(results['mean_test_score'], results['params']):
    print(f"{params}: {mean_score:.3f}")

print("Individual fold scores:")
print(results['split0_test_score'])
print(results['split1_test_score'])
print(results['split2_test_score'])

acc_i,mapping_i = label_permute_score_perm(y_train, grid_search.predict(X_train), n=n_components)
print(acc_i,mapping_i)

accuracy_score_i = grid_search.score(X_test,y_test)
y_pred = grid_search.predict(X_test)
y_pred = [mapping_i.get(w) for w in y_pred]
print("Accuracy:",accuracy_score_i)
print(classification_report(y_test,y_pred))

i =len(df_results)
df_results.at[i,"Model"] = "Unsupervised - NMF"
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
# Amount trained on y_train==1 i.e. DIED; shows the imbalance is not there, but still learned well
print(1-len(y_train[y_train==1])/len(y_train))
print(1-len(y_test[y_test==1])/len(y_test))
balance_train = 1-len(y_train[y_train==1])/len(y_train)
balance_test = 1-len(y_test[y_test==1])/len(y_test)
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# 9282
# Best parameters: {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}
# Best accuracy: 0.66
# Mean Test Scores for each parameter combination:
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.516
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.516
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.662
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.662
# Individual fold scores:
# [0.52504039 0.52504039 0.74151858 0.74151858]
# [0.50565428 0.50565428 0.66397415 0.66397415]
# [0.51618123 0.51618123 0.57928803 0.57928803]
# 0.6336206896551724 {0: 1, 1: 0}
# Accuracy: 0.6248316725020199
#               precision    recall  f1-score   support
#
#            0       0.69      0.47      0.56      3733
#            1       0.59      0.78      0.67      3693
#
#     accuracy                           0.62      7426
#    macro avg       0.64      0.63      0.62      7426
# weighted avg       0.64      0.62      0.62      7426
#
# 0.4892241379310345
# 0.5026932399676811
#               precision    recall  f1-score   support
#
#            0       0.69      0.47      0.56      3733
#            1       0.59      0.78      0.67      3693
#
#     accuracy                           0.62      7426
#    macro avg       0.64      0.63      0.62      7426
# weighted avg       0.64      0.62      0.62      7426

# %% [markdown]
# ### 2.2.2.1 Supervised ML - XGBoostClassifier - test_size = 0.8 - UNDERSAMPLE w/ random_state = 43

# %%
Section = "2.2.2.1"
description = "Supervised ML - XGBoost"
param_grid = {
    'classifier__learning_rate': [0.05, 0.1]
}
xgb_clf = xgb.XGBClassifier(random_state=random_state)
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', xgb_clf)
])

grid_search = GridSearchCV(model_pipeline, param_grid, cv=3, n_jobs=-1)
grid_search.fit(X_train, y_train)
print("Best parameters:", grid_search.best_params_)
y_pred = grid_search.predict(X_test)
accuracy_score_i =accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_score_i)
print(classification_report(y_test, y_pred))
i =len(df_results)
df_results.at[i,"Model"] = description
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# Best parameters: {'classifier__learning_rate': 0.1}
# Accuracy: 0.8501211957985456
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86      3733
#            1       0.87      0.82      0.84      3693
#
#     accuracy                           0.85      7426
#    macro avg       0.85      0.85      0.85      7426
# weighted avg       0.85      0.85      0.85      7426
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86      3733
#            1       0.87      0.82      0.84      3693
#
#     accuracy                           0.85      7426
#    macro avg       0.85      0.85      0.85      7426
# weighted avg       0.85      0.85      0.85      7426

# %% [markdown]
# ### 2.2.3 Unsupervised ML - NMF - test_size = 0.2 - UNDERSAMPLE w/ random_state = 42

# %%
Section = "2.2.3"
random_state = 42
test_size = 0.2
description = f"Unsupervised ML - NMF - test_size = {test_size} = UNDERSAMPLE w/ random_state = {random_state}"
df_COVID_dead = df_COVID[df_COVID["DIED"]==1]
df_COVID_alive = df_COVID[df_COVID["DIED"]!=1]
df_COVID_alive_sample = df_COVID_alive.sample(n=num_DEAD,random_state=random_state).reset_index().drop("index",axis=1) # UNDERSAMPLE
df = pd.concat([df_COVID_dead,df_COVID_alive_sample],axis=0).reset_index().drop("index",axis=1)
X = df[categorical_features + numerical_features + text_features]
y = df['DIED']  
print(len(df))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

n_components = len(df_COVID["DIED"].unique())
tfidvec = TfidfVectorizer(min_df=5,max_df=0.9,ngram_range=(1,2),tokenizer=word_tokenize,stop_words = 'english')
nmf_classifier = NMFClassifier(n_components=n_components)
preprocessor = ColumnTransformer(
    transformers=[
        ('tfidf', tfidvec, 'SYMPTOMS'),
    ]
)
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('nmf', nmf_classifier)
])
param_grid = {
    'nmf__l1_ratio': [0.5, 0.0],
    'nmf__solver': ['mu'],
    'nmf__beta_loss': ['frobenius', 'kullback-leibler'],
}
custom_scorer = make_scorer(lambda y_true, yp: label_permute_score(y_true, yp, n=n_components))
grid_search = GridSearchCV(pipeline, param_grid, scoring=custom_scorer, cv=3)
grid_search.fit(X_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best accuracy: {grid_search.best_score_:.2f}")
results = grid_search.cv_results_
print("Mean Test Scores for each parameter combination:")
for mean_score, params in zip(results['mean_test_score'], results['params']):
    print(f"{params}: {mean_score:.3f}")

print("Individual fold scores:")
print(results['split0_test_score'])
print(results['split1_test_score'])
print(results['split2_test_score'])

acc_i,mapping_i = label_permute_score_perm(y_train, grid_search.predict(X_train), n=n_components)
print(acc_i,mapping_i)

accuracy_score_i = grid_search.score(X_test,y_test)
y_pred = grid_search.predict(X_test)
y_pred = [mapping_i.get(w) for w in y_pred]
print("Accuracy:",accuracy_score_i)
print(classification_report(y_test,y_pred))

i =len(df_results)
df_results.at[i,"Model"] = "Unsupervised - NMF"
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
# Amount trained on y_train==1 i.e. DIED; shows the imbalance is not there, but still learned well
print(1-len(y_train[y_train==1])/len(y_train))
print(1-len(y_test[y_test==1])/len(y_test))
balance_train = 1-len(y_train[y_train==1])/len(y_train)
balance_test = 1-len(y_test[y_test==1])/len(y_test)
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# 9282
# Best parameters: {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}
# Best accuracy: 0.84
# Mean Test Scores for each parameter combination:
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.819
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.819
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.841
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.841
# Individual fold scores:
# [0.8230303  0.8230303  0.84646465 0.84646465]
# [0.81171717 0.81171717 0.8379798  0.8379798 ]
# [0.82181818 0.82181818 0.83838384 0.83838384]
# 0.8432323232323232 {0: 1, 1: 0}
# Accuracy: 0.84760366182014
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84       946
#            1       0.82      0.89      0.85       911
#
#     accuracy                           0.85      1857
#    macro avg       0.85      0.85      0.85      1857
# weighted avg       0.85      0.85      0.85      1857
#
# 0.49764309764309766
# 0.5094238018309101
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84       946
#            1       0.82      0.89      0.85       911
#
#     accuracy                           0.85      1857
#    macro avg       0.85      0.85      0.85      1857
# weighted avg       0.85      0.85      0.85      1857

# %% [markdown]
# #### 2.2.3.1 Supervised ML - XGBoostClassifier - test_size = 0.2 - UNDERSAMPLE w/ random_state = 42

# %%
Section = "2.2.3.1"
description = "Supervised ML - XGBoost"
param_grid = {
    'classifier__learning_rate': [0.05, 0.1]
}
xgb_clf = xgb.XGBClassifier(random_state=random_state)
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', xgb_clf)
])

grid_search = GridSearchCV(model_pipeline, param_grid, cv=3, n_jobs=-1)
grid_search.fit(X_train, y_train)
print("Best parameters:", grid_search.best_params_)
y_pred = grid_search.predict(X_test)
accuracy_score_i =accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_score_i)
print(classification_report(y_test, y_pred))
i =len(df_results)
df_results.at[i,"Model"] = description
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# Best parameters: {'classifier__learning_rate': 0.1}
# Accuracy: 0.8777598276790523
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       946
#            1       0.89      0.86      0.87       911
#
#     accuracy                           0.88      1857
#    macro avg       0.88      0.88      0.88      1857
# weighted avg       0.88      0.88      0.88      1857
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       946
#            1       0.89      0.86      0.87       911
#
#     accuracy                           0.88      1857
#    macro avg       0.88      0.88      0.88      1857
# weighted avg       0.88      0.88      0.88      1857

# %% [markdown]
# ### 2.2.4 Unsupervised ML - NMF - test_size = 0.2 - IMBALANCED on ALL

# %%
Section = "2.2.4"
random_state = 42
test_size = 0.2
description = f"Unsupervised ML - NMF - test_size = {test_size} = IMBALANCED on ALL w/ random_state = {random_state}"
df_COVID_dead = df_COVID[df_COVID["DIED"]==1]
df_COVID_alive = df_COVID[df_COVID["DIED"]!=1]
df_COVID_alive_sample = df_COVID_alive.sample(n=num_DEAD,random_state=random_state).reset_index().drop("index",axis=1) # UNDERSAMPLE
df = pd.concat([df_COVID_dead,df_COVID_alive],axis=0).reset_index().drop("index",axis=1)
X = df[categorical_features + numerical_features + text_features]
y = df['DIED']  
print(len(df))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

n_components = len(df_COVID["DIED"].unique())
tfidvec = TfidfVectorizer(min_df=5,max_df=0.9,ngram_range=(1,2),tokenizer=word_tokenize,stop_words = 'english')
nmf_classifier = NMFClassifier(n_components=n_components)
preprocessor = ColumnTransformer(
    transformers=[
        ('tfidf', tfidvec, 'SYMPTOMS'),
    ]
)
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('nmf', nmf_classifier)
])
param_grid = {
    'nmf__l1_ratio': [0.5, 0.0],
    'nmf__solver': ['mu'],
    'nmf__beta_loss': ['frobenius', 'kullback-leibler'],
}
custom_scorer = make_scorer(lambda y_true, yp: label_permute_score(y_true, yp, n=n_components))
grid_search = GridSearchCV(pipeline, param_grid, scoring=custom_scorer, cv=3)
grid_search.fit(X_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best accuracy: {grid_search.best_score_:.2f}")
results = grid_search.cv_results_
print("Mean Test Scores for each parameter combination:")
for mean_score, params in zip(results['mean_test_score'], results['params']):
    print(f"{params}: {mean_score:.3f}")

print("Individual fold scores:")
print(results['split0_test_score'])
print(results['split1_test_score'])
print(results['split2_test_score'])

acc_i,mapping_i = label_permute_score_perm(y_train, grid_search.predict(X_train), n=n_components)
print(acc_i,mapping_i)

accuracy_score_i = grid_search.score(X_test,y_test)
y_pred = grid_search.predict(X_test)
y_pred = [mapping_i.get(w) for w in y_pred]
print("Accuracy:",accuracy_score_i)
print(classification_report(y_test,y_pred))

i =len(df_results)
df_results.at[i,"Model"] = "Unsupervised - NMF"
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
# Amount trained on y_train==1 i.e. DIED; shows the imbalance is not there, but still learned well
print(1-len(y_train[y_train==1])/len(y_train))
print(1-len(y_test[y_test==1])/len(y_test))
balance_train = 1-len(y_train[y_train==1])/len(y_train)
balance_test = 1-len(y_test[y_test==1])/len(y_test)
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# 897843
# Best parameters: {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}
# Best accuracy: 0.88
# Mean Test Scores for each parameter combination:
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.875
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.875
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.794
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.794
# Individual fold scores:
# [0.8744492  0.8744492  0.79100345 0.79100345]
# [0.87519683 0.87519683 0.79272841 0.79272841]
# [0.87556385 0.87556385 0.79697106 0.79697106]
# 0.8751005883548618 {0: 0, 1: 1}
# Accuracy: 0.8747445271733986
#               precision    recall  f1-score   support
#
#            0       0.99      0.88      0.93    178664
#            1       0.00      0.02      0.00       905
#
#     accuracy                           0.87    179569
#    macro avg       0.50      0.45      0.47    179569
# weighted avg       0.99      0.87      0.93    179569
#
# 0.994798642300849
# 0.9949601545923851
#               precision    recall  f1-score   support
#
#            0       0.99      0.88      0.93    178664
#            1       0.00      0.02      0.00       905
#
#     accuracy                           0.87    179569
#    macro avg       0.50      0.45      0.47    179569
# weighted avg       0.99      0.87      0.93    179569

# %% [markdown]
# #### 2.2.4.1 Supervised ML - XGBoostClassifier - test_size = 0.2 - IMBALANCED on ALL

# %%
Section = "2.2.4.1"
description = "Supervised ML - XGBoost"
param_grid = {
    'classifier__learning_rate': [0.05, 0.1]
}
xgb_clf = xgb.XGBClassifier(random_state=random_state)
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', xgb_clf)
])

grid_search = GridSearchCV(model_pipeline, param_grid, cv=3, n_jobs=-1)
grid_search.fit(X_train, y_train)
print("Best parameters:", grid_search.best_params_)
y_pred = grid_search.predict(X_test)
accuracy_score_i =accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_score_i)
print(classification_report(y_test, y_pred))
i =len(df_results)
df_results.at[i,"Model"] = description
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# Best parameters: {'classifier__learning_rate': 0.1}
# Accuracy: 0.995160634630699
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    178664
#            1       0.71      0.07      0.12       905
#
#     accuracy                           1.00    179569
#    macro avg       0.85      0.53      0.56    179569
# weighted avg       0.99      1.00      0.99    179569
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    178664
#            1       0.71      0.07      0.12       905
#
#     accuracy                           1.00    179569
#    macro avg       0.85      0.53      0.56    179569
# weighted avg       0.99      1.00      0.99    179569

# %% [markdown]
# ### 2.2.5 Unsupervised ML - NMF - test_size = 0.8 - IMBALANCED on ALL

# %%
Section = "2.2.5"
random_state = 42
test_size = 0.8
description = f"Unsupervised ML - NMF - test_size = {test_size} = IMBALANCED on ALL w/ random_state = {random_state}"
df_COVID_dead = df_COVID[df_COVID["DIED"]==1]
df_COVID_alive = df_COVID[df_COVID["DIED"]!=1]
df_COVID_alive_sample = df_COVID_alive.sample(n=num_DEAD,random_state=random_state).reset_index().drop("index",axis=1) # UNDERSAMPLE
df = pd.concat([df_COVID_dead,df_COVID_alive],axis=0).reset_index().drop("index",axis=1)
X = df[categorical_features + numerical_features + text_features]
y = df['DIED']  
print(len(df))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

n_components = len(df_COVID["DIED"].unique())
tfidvec = TfidfVectorizer(min_df=5,max_df=0.9,ngram_range=(1,2),tokenizer=word_tokenize,stop_words = 'english')
nmf_classifier = NMFClassifier(n_components=n_components)
preprocessor = ColumnTransformer(
    transformers=[
        ('tfidf', tfidvec, 'SYMPTOMS'),
    ]
)
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('nmf', nmf_classifier)
])
param_grid = {
    'nmf__l1_ratio': [0.5, 0.0],
    'nmf__solver': ['mu'],
    'nmf__beta_loss': ['frobenius', 'kullback-leibler'],
}
custom_scorer = make_scorer(lambda y_true, yp: label_permute_score(y_true, yp, n=n_components))
grid_search = GridSearchCV(pipeline, param_grid, scoring=custom_scorer, cv=3)
grid_search.fit(X_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best accuracy: {grid_search.best_score_:.2f}")
results = grid_search.cv_results_
print("Mean Test Scores for each parameter combination:")
for mean_score, params in zip(results['mean_test_score'], results['params']):
    print(f"{params}: {mean_score:.3f}")

print("Individual fold scores:")
print(results['split0_test_score'])
print(results['split1_test_score'])
print(results['split2_test_score'])

acc_i,mapping_i = label_permute_score_perm(y_train, grid_search.predict(X_train), n=n_components)
print(acc_i,mapping_i)

accuracy_score_i = grid_search.score(X_test,y_test)
y_pred = grid_search.predict(X_test)
y_pred = [mapping_i.get(w) for w in y_pred]
print("Accuracy:",accuracy_score_i)
print(classification_report(y_test,y_pred))

i =len(df_results)
df_results.at[i,"Model"] = "Unsupervised - NMF"
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
# Amount trained on y_train==1 i.e. DIED; shows the imbalance is not there, but still learned well
print(1-len(y_train[y_train==1])/len(y_train))
print(1-len(y_test[y_test==1])/len(y_test))
balance_train = 1-len(y_train[y_train==1])/len(y_train)
balance_test = 1-len(y_test[y_test==1])/len(y_test)
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# 897843
# Best parameters: {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}
# Best accuracy: 0.88
# Mean Test Scores for each parameter combination:
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.875
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.875
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.785
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.785
# Individual fold scores:
# [0.87538426 0.87538426 0.78932772 0.78932772]
# [0.87640337 0.87640337 0.78495055 0.78495055]
# [0.87441526 0.87441526 0.78204357 0.78204357]
# 0.875529047491758 {0: 0, 1: 1}
# Accuracy: 0.8748083951132922
#               precision    recall  f1-score   support
#
#            0       0.99      0.88      0.93    714554
#            1       0.00      0.02      0.00      3721
#
#     accuracy                           0.87    718275
#    macro avg       0.50      0.45      0.47    718275
# weighted avg       0.99      0.87      0.93    718275
#
# 0.9948765927113963
# 0.9948195329087048
#               precision    recall  f1-score   support
#
#            0       0.99      0.88      0.93    714554
#            1       0.00      0.02      0.00      3721
#
#     accuracy                           0.87    718275
#    macro avg       0.50      0.45      0.47    718275
# weighted avg       0.99      0.87      0.93    718275

# %% [markdown]
# ### 2.2.5.1 Supervised ML - XGBoostClassifier - test_size = 0.8 - IMBALANCED on ALL

# %%
Section = "2.2.5.1"
description = "Supervised ML - XGBoost"
param_grid = {
    'classifier__learning_rate': [0.05, 0.1]
}
xgb_clf = xgb.XGBClassifier(random_state=random_state)
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', xgb_clf)
])

grid_search = GridSearchCV(model_pipeline, param_grid, cv=3, n_jobs=-1)
grid_search.fit(X_train, y_train)
print("Best parameters:", grid_search.best_params_)
y_pred = grid_search.predict(X_test)
accuracy_score_i =accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_score_i)
print(classification_report(y_test, y_pred))
i =len(df_results)
df_results.at[i,"Model"] = description
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# Best parameters: {'classifier__learning_rate': 0.05}
# Accuracy: 0.9950506421635168
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    714554
#            1       0.71      0.08      0.14      3721
#
#     accuracy                           1.00    718275
#    macro avg       0.85      0.54      0.57    718275
# weighted avg       0.99      1.00      0.99    718275
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    714554
#            1       0.71      0.08      0.14      3721
#
#     accuracy                           1.00    718275
#    macro avg       0.85      0.54      0.57    718275
# weighted avg       0.99      1.00      0.99    718275

# %% [markdown]
# ### 2.2.6 Unsupervised ML - NMF - test_size = 0.2 - IMBALANCED Testing on ALL

# %%
Section = "2.2.6"
random_state = 42
test_size = 0.2
description = f"Unsupervised ML - NMF - test_size = {test_size} = IMBALANCED Testing on ALL w/ random_state = {random_state}"


df_COVID_dead = df_COVID[df_COVID["DIED"]==1]
df_COVID_alive = df_COVID[df_COVID["DIED"]!=1]
df_COVID_alive_sample = df_COVID_alive.sample(n=num_DEAD,random_state=random_state).reset_index().drop("index",axis=1) # UNDERSAMPLE
df_COVID_alive_remaining = df_COVID_alive[~df_COVID_alive.VAERS_ID.isin(list(df_COVID_alive_sample.VAERS_ID))] # remaining
df = pd.concat([df_COVID_dead,df_COVID_alive_sample],axis=0).reset_index().drop("index",axis=1)
X = df[categorical_features + numerical_features + text_features]
y = df['DIED']  
print(len(df))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
X_rem = df_COVID_alive_remaining[categorical_features + numerical_features + text_features]
y_rem = df_COVID_alive_remaining["DIED"]

X_test_comb = pd.concat([X_test,X_rem],axis=0)
y_test_comb = pd.concat([y_test,y_rem],axis=0)
X_test = X_test_comb
y_test = y_test_comb

n_components = len(df_COVID["DIED"].unique())
tfidvec = TfidfVectorizer(min_df=5,max_df=0.9,ngram_range=(1,2),tokenizer=word_tokenize,stop_words = 'english')
nmf_classifier = NMFClassifier(n_components=n_components)
preprocessor = ColumnTransformer(
    transformers=[
        ('tfidf', tfidvec, 'SYMPTOMS'),
    ]
)
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('nmf', nmf_classifier)
])
param_grid = {
    'nmf__l1_ratio': [0.5, 0.0],
    'nmf__solver': ['mu'],
    'nmf__beta_loss': ['frobenius', 'kullback-leibler'],
}
custom_scorer = make_scorer(lambda y_true, yp: label_permute_score(y_true, yp, n=n_components))
grid_search = GridSearchCV(pipeline, param_grid, scoring=custom_scorer, cv=3)
grid_search.fit(X_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best accuracy: {grid_search.best_score_:.2f}")
results = grid_search.cv_results_
print("Mean Test Scores for each parameter combination:")
for mean_score, params in zip(results['mean_test_score'], results['params']):
    print(f"{params}: {mean_score:.3f}")

print("Individual fold scores:")
print(results['split0_test_score'])
print(results['split1_test_score'])
print(results['split2_test_score'])

acc_i,mapping_i = label_permute_score_perm(y_train, grid_search.predict(X_train), n=n_components)
print(acc_i,mapping_i)

accuracy_score_i = grid_search.score(X_test,y_test)
y_pred = grid_search.predict(X_test)
y_pred = [mapping_i.get(w) for w in y_pred]
print("Accuracy:",accuracy_score_i)
print(classification_report(y_test,y_pred))

i =len(df_results)
df_results.at[i,"Model"] = "Unsupervised - NMF"
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
# Amount trained on y_train==1 i.e. DIED; shows the imbalance is not there, but still learned well
print(1-len(y_train[y_train==1])/len(y_train))
print(1-len(y_test[y_test==1])/len(y_test))
balance_train = 1-len(y_train[y_train==1])/len(y_train)
balance_test = 1-len(y_test[y_test==1])/len(y_test)
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# 9282
# Best parameters: {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}
# Best accuracy: 0.84
# Mean Test Scores for each parameter combination:
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.819
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.819
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.841
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.841
# Individual fold scores:
# [0.8230303  0.8230303  0.84646465 0.84646465]
# [0.81171717 0.81171717 0.8379798  0.8379798 ]
# [0.82181818 0.82181818 0.83838384 0.83838384]
# 0.8432323232323232 {0: 1, 1: 0}
# Accuracy: 0.7878737851211454
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88    889507
#            1       0.00      0.89      0.01       911
#
#     accuracy                           0.79    890418
#    macro avg       0.50      0.84      0.44    890418
# weighted avg       1.00      0.79      0.88    890418
#
# 0.49764309764309766
# 0.9989768850135554
#               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88    889507
#            1       0.00      0.89      0.01       911
#
#     accuracy                           0.79    890418
#    macro avg       0.50      0.84      0.44    890418
# weighted avg       1.00      0.79      0.88    890418

# %% [markdown]
# ### 2.2.6.1 Supervised ML - XGBoostClassifier - test_size = 0.2 - IMBALANCED Testing on ALL

# %%
Section = "2.2.6.1"
description = "Supervised ML - XGBoost"
param_grid = {
    'classifier__learning_rate': [0.05, 0.1]
}
xgb_clf = xgb.XGBClassifier(random_state=random_state)
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', xgb_clf)
])

grid_search = GridSearchCV(model_pipeline, param_grid, cv=3, n_jobs=-1)
grid_search.fit(X_train, y_train)
print("Best parameters:", grid_search.best_params_)
y_pred = grid_search.predict(X_test)
accuracy_score_i =accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_score_i)
print(classification_report(y_test, y_pred))
i =len(df_results)
df_results.at[i,"Model"] = description
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# Best parameters: {'classifier__learning_rate': 0.1}
# Accuracy: 0.8927200483368485
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94    889507
#            1       0.01      0.86      0.02       911
#
#     accuracy                           0.89    890418
#    macro avg       0.50      0.88      0.48    890418
# weighted avg       1.00      0.89      0.94    890418
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94    889507
#            1       0.01      0.86      0.02       911
#
#     accuracy                           0.89    890418
#    macro avg       0.50      0.88      0.48    890418
# weighted avg       1.00      0.89      0.94    890418

# %% [markdown]
# ### 2.2.7 Unsupervised ML - NMF - test_size = 0.8 - IMBALANCED Testing on ALL

# %%
Section = "2.2.7"
random_state = 42
test_size = 0.8
description = f"Unsupervised ML - NMF - test_size = {test_size} = IMBALANCED Testing on ALL w/ random_state = {random_state}"
df_COVID_dead = df_COVID[df_COVID["DIED"]==1]
df_COVID_alive = df_COVID[df_COVID["DIED"]!=1]
df_COVID_alive_sample = df_COVID_alive.sample(n=num_DEAD,random_state=random_state).reset_index().drop("index",axis=1) # UNDERSAMPLE
df_COVID_alive_remaining = df_COVID_alive[~df_COVID_alive.VAERS_ID.isin(list(df_COVID_alive_sample.VAERS_ID))] # remaining
df = pd.concat([df_COVID_dead,df_COVID_alive_sample],axis=0).reset_index().drop("index",axis=1)
X = df[categorical_features + numerical_features + text_features]
y = df['DIED']  
print(len(df))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
X_rem = df_COVID_alive_remaining[categorical_features + numerical_features + text_features]
y_rem = df_COVID_alive_remaining["DIED"]

X_test_comb = pd.concat([X_test,X_rem],axis=0)
y_test_comb = pd.concat([y_test,y_rem],axis=0)
X_test = X_test_comb
y_test = y_test_comb

n_components = len(df_COVID["DIED"].unique())
tfidvec = TfidfVectorizer(min_df=5,max_df=0.9,ngram_range=(1,2),tokenizer=word_tokenize,stop_words = 'english')
nmf_classifier = NMFClassifier(n_components=n_components)
preprocessor = ColumnTransformer(
    transformers=[
        ('tfidf', tfidvec, 'SYMPTOMS'),
    ]
)
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('nmf', nmf_classifier)
])
param_grid = {
    'nmf__l1_ratio': [0.5, 0.0],
    'nmf__solver': ['mu'],
    'nmf__beta_loss': ['frobenius', 'kullback-leibler'],
}
custom_scorer = make_scorer(lambda y_true, yp: label_permute_score(y_true, yp, n=n_components))
grid_search = GridSearchCV(pipeline, param_grid, scoring=custom_scorer, cv=3)
grid_search.fit(X_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best accuracy: {grid_search.best_score_:.2f}")
results = grid_search.cv_results_
print("Mean Test Scores for each parameter combination:")
for mean_score, params in zip(results['mean_test_score'], results['params']):
    print(f"{params}: {mean_score:.3f}")

print("Individual fold scores:")
print(results['split0_test_score'])
print(results['split1_test_score'])
print(results['split2_test_score'])

acc_i,mapping_i = label_permute_score_perm(y_train, grid_search.predict(X_train), n=n_components)
print(acc_i,mapping_i)

accuracy_score_i = grid_search.score(X_test,y_test)
y_pred = grid_search.predict(X_test)
y_pred = [mapping_i.get(w) for w in y_pred]
print("Accuracy:",accuracy_score_i)
print(classification_report(y_test,y_pred))

i =len(df_results)
df_results.at[i,"Model"] = "Unsupervised - NMF"
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
# Amount trained on y_train==1 i.e. DIED; shows the imbalance is not there, but still learned well
print(1-len(y_train[y_train==1])/len(y_train))
print(1-len(y_test[y_test==1])/len(y_test))
balance_train = 1-len(y_train[y_train==1])/len(y_train)
balance_test = 1-len(y_test[y_test==1])/len(y_test)
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# 9282
# Best parameters: {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}
# Best accuracy: 0.82
# Mean Test Scores for each parameter combination:
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.810
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.810
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.816
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.816
# Individual fold scores:
# [0.82875606 0.82875606 0.83521809 0.83521809]
# [0.80129241 0.80129241 0.80452342 0.80452342]
# [0.80097087 0.80097087 0.80906149 0.80906149]
# 0.8227370689655172 {0: 1, 1: 0}
# Accuracy: 0.8398559354097771
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91    892292
#            1       0.02      0.79      0.04      3695
#
#     accuracy                           0.84    895987
#    macro avg       0.51      0.82      0.48    895987
# weighted avg       0.99      0.84      0.91    895987
#
# 0.49030172413793105
# 0.995876056237423
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91    892292
#            1       0.02      0.79      0.04      3695
#
#     accuracy                           0.84    895987
#    macro avg       0.51      0.82      0.48    895987
# weighted avg       0.99      0.84      0.91    895987

# %% [markdown]
# #### 2.2.7.1 Supervised ML - XGBoostClassifier - test_size = 0.8 - IMBALANCED Testing on ALL

# %%
Section = "2.2.7.1"
description = "Supervised ML - XGBoost"
param_grid = {
    'classifier__learning_rate': [0.05, 0.1]
}
xgb_clf = xgb.XGBClassifier(random_state=random_state)
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', xgb_clf)
])

grid_search = GridSearchCV(model_pipeline, param_grid, cv=3, n_jobs=-1)
grid_search.fit(X_train, y_train)
print("Best parameters:", grid_search.best_params_)
y_pred = grid_search.predict(X_test)
accuracy_score_i =accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_score_i)
print(classification_report(y_test, y_pred))
i =len(df_results)
df_results.at[i,"Model"] = description
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# Best parameters: {'classifier__learning_rate': 0.1}
# Accuracy: 0.8806232679715219
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94    892292
#            1       0.03      0.81      0.05      3695
#
#     accuracy                           0.88    895987
#    macro avg       0.51      0.85      0.49    895987
# weighted avg       1.00      0.88      0.93    895987
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94    892292
#            1       0.03      0.81      0.05      3695
#
#     accuracy                           0.88    895987
#    macro avg       0.51      0.85      0.49    895987
# weighted avg       1.00      0.88      0.93    895987

# %% [markdown]
# ### 2.2.8 Unsupervised ML - NMF - test_size = 0.8 - OVERSAMPLE Testing on ALL

# %%
Section = "2.2.8"
random_state = 42
test_size = 0.8
description = f"Unsupervised ML - NMF - test_size = {test_size} = OVERSAMPLE Testing on ALL w/ random_state = {random_state}"
df_COVID_dead = df_COVID[df_COVID["DIED"]==1]
df_COVID_alive = df_COVID[df_COVID["DIED"]!=1]

    
df_COVID_alive_sample = df_COVID_alive.sample(n=num_DEAD,random_state=random_state).reset_index().drop("index",axis=1) # UNDERSAMPLE
df_COVID_alive_remaining = df_COVID_alive[~df_COVID_alive.VAERS_ID.isin(list(df_COVID_alive_sample.VAERS_ID))] # remaining
df = pd.concat([df_COVID_dead,df_COVID_alive],axis=0).reset_index().drop("index",axis=1)
X = df[categorical_features + numerical_features + text_features]
y = df['DIED']  
print(len(df))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
# X_rem = df_COVID_alive_remaining[categorical_features + numerical_features + text_features]
# y_rem = df_COVID_alive_remaining["DIED"]

num_y_dead = len(y_train[y_train==1])
num_y_alive = len(y_train[y_train!=1]) #+ len(y_rem)
y_died = y_train[y_train==1]
X_died = X_train.loc[y_died.index.to_list()]
while num_y_dead < num_y_alive: #oversampling
    X_train = pd.concat([X_train,X_died],axis=0)
    y_train = pd.concat([y_train,y_died],axis=0)
    num_y_dead = len(y_train[y_train==1])
print("len(y_train)",len(y_train))
# X_test_comb = pd.concat([X_test,X_rem],axis=0)
# y_test_comb = pd.concat([y_test,y_rem],axis=0)
# X_test = X_test_comb
# y_test = y_test_comb

n_components = len(df_COVID["DIED"].unique())
tfidvec = TfidfVectorizer(min_df=5,max_df=0.9,ngram_range=(1,2),tokenizer=word_tokenize,stop_words = 'english')
nmf_classifier = NMFClassifier(n_components=n_components)
preprocessor = ColumnTransformer(
    transformers=[
        ('tfidf', tfidvec, 'SYMPTOMS'),
    ]
)
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('nmf', nmf_classifier)
])
param_grid = {
    'nmf__l1_ratio': [0.5, 0.0],
    'nmf__solver': ['mu'],
    'nmf__beta_loss': ['frobenius', 'kullback-leibler'],
}
custom_scorer = make_scorer(lambda y_true, yp: label_permute_score(y_true, yp, n=n_components))
grid_search = GridSearchCV(pipeline, param_grid, scoring=custom_scorer, cv=3)
grid_search.fit(X_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best accuracy: {grid_search.best_score_:.2f}")
results = grid_search.cv_results_
print("Mean Test Scores for each parameter combination:")
for mean_score, params in zip(results['mean_test_score'], results['params']):
    print(f"{params}: {mean_score:.3f}")

print("Individual fold scores:")
print(results['split0_test_score'])
print(results['split1_test_score'])
print(results['split2_test_score'])

acc_i,mapping_i = label_permute_score_perm(y_train, grid_search.predict(X_train), n=n_components)
print(acc_i,mapping_i)

accuracy_score_i = grid_search.score(X_test,y_test)
y_pred = grid_search.predict(X_test)
y_pred = [mapping_i.get(w) for w in y_pred]
print("Accuracy:",accuracy_score_i)
print(classification_report(y_test,y_pred))

i =len(df_results)
df_results.at[i,"Model"] = "Unsupervised - NMF"
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
# Amount trained on y_train==1 i.e. DIED; shows the imbalance is not there, but still learned well
print(1-len(y_train[y_train==1])/len(y_train))
print(1-len(y_test[y_test==1])/len(y_test))
balance_train = 1-len(y_train[y_train==1])/len(y_train)
balance_test = 1-len(y_test[y_test==1])/len(y_test)
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# 897843
# len(y_train) 358048
# Best parameters: {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}
# Best accuracy: 0.89
# Mean Test Scores for each parameter combination:
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.778
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.778
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.895
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.895
# Individual fold scores:
# [0.62423125 0.62423125 0.92115626 0.92115626]
# [0.76372655 0.76372655 0.82448114 0.82448114]
# [0.9456468  0.9456468  0.93911972 0.93911972]
# 0.8221579229600501 {0: 1, 1: 0}
# Accuracy: 0.8444119592078243
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.92    714554
#            1       0.03      0.78      0.05      3721
#
#     accuracy                           0.84    718275
#    macro avg       0.51      0.81      0.48    718275
# weighted avg       0.99      0.84      0.91    718275
#
# 0.49894986147108766
# 0.9948195329087048
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.92    714554
#            1       0.03      0.78      0.05      3721
#
#     accuracy                           0.84    718275
#    macro avg       0.51      0.81      0.48    718275
# weighted avg       0.99      0.84      0.91    718275

# %% [markdown]
# ### 2.2.8.1 Supervised ML - XGBoostClassifier - test_size = 0.8 - OVERSAMPLE Testing on ALL

# %%
Section = "2.2.8.1"
description = "Supervised ML - XGBoost"
param_grid = {
    'classifier__learning_rate': [0.05, 0.1]
}
xgb_clf = xgb.XGBClassifier(random_state=random_state)
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', xgb_clf)
])

grid_search = GridSearchCV(model_pipeline, param_grid, cv=3, n_jobs=-1)
grid_search.fit(X_train, y_train)
print("Best parameters:", grid_search.best_params_)
y_pred = grid_search.predict(X_test)
accuracy_score_i =accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_score_i)
print(classification_report(y_test, y_pred))
i =len(df_results)
df_results.at[i,"Model"] = description
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# Best parameters: {'classifier__learning_rate': 0.1}
# Accuracy: 0.9209536737322056
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96    714554
#            1       0.05      0.74      0.09      3721
#
#     accuracy                           0.92    718275
#    macro avg       0.52      0.83      0.52    718275
# weighted avg       0.99      0.92      0.95    718275
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96    714554
#            1       0.05      0.74      0.09      3721
#
#     accuracy                           0.92    718275
#    macro avg       0.52      0.83      0.52    718275
# weighted avg       0.99      0.92      0.95    718275

# %% [markdown]
# ### 2.2.9 Unsupervised ML - NMF - test_size = 0.2 - OVERSAMPLE Testing on ALL

# %%
Section = "2.2.9"
random_state = 42
test_size = 0.2
description = f"Unsupervised ML - NMF - test_size = {test_size} = OVERSAMPLE Testing on ALL w/ random_state = {random_state}"
df_COVID_dead = df_COVID[df_COVID["DIED"]==1]
df_COVID_alive = df_COVID[df_COVID["DIED"]!=1]

    
df_COVID_alive_sample = df_COVID_alive.sample(n=num_DEAD,random_state=random_state).reset_index().drop("index",axis=1) # UNDERSAMPLE
df_COVID_alive_remaining = df_COVID_alive[~df_COVID_alive.VAERS_ID.isin(list(df_COVID_alive_sample.VAERS_ID))] # remaining
df = pd.concat([df_COVID_dead,df_COVID_alive],axis=0).reset_index().drop("index",axis=1)
X = df[categorical_features + numerical_features + text_features]
y = df['DIED']  
print(len(df))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
# X_rem = df_COVID_alive_remaining[categorical_features + numerical_features + text_features]
# y_rem = df_COVID_alive_remaining["DIED"]

num_y_dead = len(y_train[y_train==1])
num_y_alive = len(y_train[y_train!=1]) #+ len(y_rem)
y_died = y_train[y_train==1]
X_died = X_train.loc[y_died.index.to_list()]
while num_y_dead < num_y_alive: #oversampling
    X_train = pd.concat([X_train,X_died],axis=0)
    y_train = pd.concat([y_train,y_died],axis=0)
    num_y_dead = len(y_train[y_train==1])
print("len(y_train)",len(y_train))
# X_test_comb = pd.concat([X_test,X_rem],axis=0)
# y_test_comb = pd.concat([y_test,y_rem],axis=0)
# X_test = X_test_comb
# y_test = y_test_comb

n_components = len(df_COVID["DIED"].unique())
tfidvec = TfidfVectorizer(min_df=5,max_df=0.9,ngram_range=(1,2),tokenizer=word_tokenize,stop_words = 'english')
nmf_classifier = NMFClassifier(n_components=n_components)
preprocessor = ColumnTransformer(
    transformers=[
        ('tfidf', tfidvec, 'SYMPTOMS'),
    ]
)
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('nmf', nmf_classifier)
])
param_grid = {
    'nmf__l1_ratio': [0.5, 0.0],
    'nmf__solver': ['mu'],
    'nmf__beta_loss': ['frobenius', 'kullback-leibler'],
}
custom_scorer = make_scorer(lambda y_true, yp: label_permute_score(y_true, yp, n=n_components))
grid_search = GridSearchCV(pipeline, param_grid, scoring=custom_scorer, cv=3)
grid_search.fit(X_train, y_train)
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best accuracy: {grid_search.best_score_:.2f}")
results = grid_search.cv_results_
print("Mean Test Scores for each parameter combination:")
for mean_score, params in zip(results['mean_test_score'], results['params']):
    print(f"{params}: {mean_score:.3f}")

print("Individual fold scores:")
print(results['split0_test_score'])
print(results['split1_test_score'])
print(results['split2_test_score'])

acc_i,mapping_i = label_permute_score_perm(y_train, grid_search.predict(X_train), n=n_components)
print(acc_i,mapping_i)

accuracy_score_i = grid_search.score(X_test,y_test)
y_pred = grid_search.predict(X_test)
y_pred = [mapping_i.get(w) for w in y_pred]
print("Accuracy:",accuracy_score_i)
print(classification_report(y_test,y_pred))

i =len(df_results)
df_results.at[i,"Model"] = "Unsupervised - NMF"
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
# Amount trained on y_train==1 i.e. DIED; shows the imbalance is not there, but still learned well
print(1-len(y_train[y_train==1])/len(y_train))
print(1-len(y_test[y_test==1])/len(y_test))
balance_train = 1-len(y_train[y_train==1])/len(y_train)
balance_test = 1-len(y_test[y_test==1])/len(y_test)
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# 897843
# len(y_train) 1431850
# Best parameters: {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}
# Best accuracy: 0.90
# Mean Test Scores for each parameter combination:
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.760
# {'nmf__beta_loss': 'frobenius', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.760
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.5, 'nmf__solver': 'mu'}: 0.903
# {'nmf__beta_loss': 'kullback-leibler', 'nmf__l1_ratio': 0.0, 'nmf__solver': 'mu'}: 0.903
# Individual fold scores:
# [0.51920659 0.51920659 0.9137327  0.9137327 ]
# [0.82145603 0.82145603 0.86284867 0.86284867]
# [0.94059709 0.94059709 0.93178052 0.93178052]
# 0.8624744212033384 {0: 1, 1: 0}
# Accuracy: 0.8301989764380266
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91    178664
#            1       0.03      0.88      0.05       905
#
#     accuracy                           0.83    179569
#    macro avg       0.51      0.86      0.48    179569
# weighted avg       0.99      0.83      0.90    179569
#
# 0.49903132311345466
# 0.9949601545923851
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91    178664
#            1       0.03      0.88      0.05       905
#
#     accuracy                           0.83    179569
#    macro avg       0.51      0.86      0.48    179569
# weighted avg       0.99      0.83      0.90    179569

# %% [markdown]
# ### 2.2.9.1 Supervised ML - XGBoostClassifier - test_size = 0.2 - OVERSAMPLE Testing on ALL

# %%
Section = "2.2.9.1"
description = "Supervised ML - XGBoost"
param_grid = {
    'classifier__learning_rate': [0.05, 0.1]
}
xgb_clf = xgb.XGBClassifier(random_state=random_state)
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', xgb_clf)
])

grid_search = GridSearchCV(model_pipeline, param_grid, cv=3, n_jobs=-1)
grid_search.fit(X_train, y_train)
print("Best parameters:", grid_search.best_params_)
y_pred = grid_search.predict(X_test)
accuracy_score_i =accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy_score_i)
print(classification_report(y_test, y_pred))
i =len(df_results)
df_results.at[i,"Model"] = description
df_results.at[i,"test_size"] = test_size
df_results.at[i,"accuracy"] = accuracy_score_i
df_results.at[i,"random_state"] = random_state
df_results.at[i,"description"] = description
df_results.at[i,"balance_test"] = balance_test
df_results.at[i,"balance_train"] = balance_train
cr_i = classification_report(y_test, y_pred)
print(cr_i)
f1_score_1 = float(cr_i.split("accuracy")[0].split("\n           1")[1].split("     ")[3])
df_results.at[i,"f1_score_1"] = f1_score_1
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Confusion Matrix - {description}', fontsize=16)
plt.show()
df_results.at[i,"gridsearch_model"] = grid_search
df_results.at[i,"Section"] = Section
# Out:
# Best parameters: {'classifier__learning_rate': 0.1}
# Accuracy: 0.913559690146963
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95    178664
#            1       0.05      0.81      0.09       905
#
#     accuracy                           0.91    179569
#    macro avg       0.52      0.86      0.52    179569
# weighted avg       0.99      0.91      0.95    179569
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95    178664
#            1       0.05      0.81      0.09       905
#
#     accuracy                           0.91    179569
#    macro avg       0.52      0.86      0.52    179569
# weighted avg       0.99      0.91      0.95    179569

# %% [markdown]
# # 3.0 Results

# %% [markdown]
# * We saw in the previous section that out of the **Unsupervised ML** method with **NMF** vs. the **Supervised ML** method with *XGBoostClassifier*, that the *XGBoostClassifier* did the best job at handling the data for creating a model that could predict if a patient was likely to die give their symptoms, vaccine information, and personal health history.
#
# * However, it was interesting how little data was required for **NMF** to do so well on the test set.  This suggests that it could learn the underlying features with a few examples better than most traditional supervised ML approaches.
#
#
# * From this we then were able to address the class imbalance above undersampling to the smaller class, **DIED** above and perform a GridSearch to see which scaled weight hyperparameter would give the best model in terms of it's *F1-Score*.
#
# * We also see that the different **random_states** didn't affect the outcome significantly, which is good.  So we can trust our **UNDERSAMPLING** results more.
#
# * Below is the result of our best hyperparameter search and model.  We see that the model has a higher *Recall* than the previous trained models and *F1-score*.  As mentioned earlier these metrics are important for the model's performance since we do not want to miss people that could likely die given their symptoms, healthy history, and vaccine information.  Thus, we care less about *False Positives* for **DIED** and more about not missing people.  So the *F1-Score* was chosen as the metrics to optimize.

# %%
df_results.sort_values(by="f1_score_1",ascending=False)
# Out:
#     Section                    Model test_size f1_score_1  accuracy  \
# 5   2.2.3.1  Supervised ML - XGBoost       0.2       0.87   0.87776
# 4     2.2.3       Unsupervised - NMF       0.2       0.85  0.847604
# 1   2.2.1.1  Supervised ML - XGBoost       0.8       0.84  0.849044
# 3   2.2.2.1  Supervised ML - XGBoost       0.8       0.84  0.850121
# 0     2.2.1       Unsupervised - NMF       0.8       0.82  0.824266
# 2     2.2.2       Unsupervised - NMF       0.8       0.67  0.624832
# 9   2.2.5.1  Supervised ML - XGBoost       0.8       0.14  0.995051
# 7   2.2.4.1  Supervised ML - XGBoost       0.2       0.12  0.995161
# 15  2.2.8.1  Supervised ML - XGBoost       0.8       0.09  0.920954
# 17  2.2.9.1  Supervised ML - XGBoost       0.2       0.09   0.91356
# 13  2.2.7.1  Supervised ML - XGBoost       0.8       0.05  0.880623
# 14    2.2.8       Unsupervised - NMF       0.8       0.05  0.844412
# 16    2.2.9       Unsupervised - NMF       0.2       0.05  0.830199
# 12    2.2.7       Unsupervised - NMF       0.8       0.04  0.839856
# 11  2.2.6.1  Supervised ML - XGBoost       0.2       0.02   0.89272
# 10    2.2.6       Unsupervised - NMF       0.2       0.01  0.787874
# 8     2.2.5       Unsupervised - NMF       0.8        0.0  0.874808
# 6     2.2.4       Unsupervised - NMF       0.2        0.0  0.874745
#
#    random_state                                        description  \
# 5            42                            Supervised ML - XGBoost
# 4            42  Unsupervised ML - NMF - test_size = 0.2 = UNDE...
# 1            42                            Supervised ML - XGBoost
# 3            43                            Supervised ML - XGBoost
# 0            42  Unsupervised ML - NMF - test_size = 0.8 = UNDE...
# 2            43  Unsupervised ML - NMF - test_size = 0.8 = UNDE...
# 9            42                            Supervised ML - XGBoost
# 7            42                            Supervised ML - XGBoost
# 15           42                            Supervised ML - XGBoost
# 17           42                            Supervised ML - XGBoost
# 13           42                            Supervised ML - XGBoost
# 14           42  Unsupervised ML - NMF - test_size = 0.8 = OVER...
# 16           42  Unsupervised ML - NMF - test_size = 0.2 = OVER...
# 12           42  Unsupervised ML - NMF - test_size = 0.8 = IMBA...
# 11           42                            Supervised ML - XGBoost
# 10           42  Unsupervised ML - NMF - test_size = 0.2 = IMBA...
# 8            42  Unsupervised ML - NMF - test_size = 0.8 = IMBA...
# 6            42  Unsupervised ML - NMF - test_size = 0.2 = IMBA...
#
#    balance_test balance_train  \
# 5      0.509424      0.497643
# 4      0.509424      0.497643
# 1      0.502424      0.490302
# 3      0.502693      0.489224
# 0      0.502424      0.490302
# 2      0.502693      0.489224
# 9       0.99482      0.994877
# 7       0.99496      0.994799
# 15      0.99482       0.49895
# 17      0.99496      0.499031
# 13     0.995876      0.490302
# 14      0.99482       0.49895
# 16      0.99496      0.499031
# 12     0.995876      0.490302
# 11     0.998977      0.497643
# 10     0.998977      0.497643
# 8       0.99482      0.994877
# 6       0.99496      0.994799
#
#                                      gridsearch_model
# 5   GridSearchCV(cv=3,\n             estimator=Pip...
# 4   GridSearchCV(cv=3,\n             estimator=Pip...
# 1   GridSearchCV(cv=3,\n             estimator=Pip...
# 3   GridSearchCV(cv=3,\n             estimator=Pip...
# 0   GridSearchCV(cv=3,\n             estimator=Pip...
# 2   GridSearchCV(cv=3,\n             estimator=Pip...
# 9   GridSearchCV(cv=3,\n             estimator=Pip...
# 7   GridSearchCV(cv=3,\n             estimator=Pip...
# 15  GridSearchCV(cv=3,\n             estimator=Pip...
# 17  GridSearchCV(cv=3,\n             estimator=Pip...
# 13  GridSearchCV(cv=3,\n             estimator=Pip...
# 14  GridSearchCV(cv=3,\n             estimator=Pip...
# 16  GridSearchCV(cv=3,\n             estimator=Pip...
# 12  GridSearchCV(cv=3,\n             estimator=Pip...
# 11  GridSearchCV(cv=3,\n             estimator=Pip...
# 10  GridSearchCV(cv=3,\n             estimator=Pip...
# 8   GridSearchCV(cv=3,\n             estimator=Pip...
# 6   GridSearchCV(cv=3,\n             estimator=Pip...

# %% [markdown]
# # 4.0 Discussion/Conclusion

# %% [markdown]
# * The goal was to determine if we could make a **UNSUPERVISED ML** model that could leverage the data in an unbiased was for predicting if a person would die or not given their health history, symptoms, and vaccine information using the VAERS dataset.  This proved to be difficult because of the imbalance in the dataset for people that died vs. people who survived, less than 1% died from this dataset.
#
# * In addition, there was a lot of data cleaning needed.  There were duplicate entries that had to be accounted for and data leakage in the symptoms for indicating **death**.  We were able to catch these issues before model training by visualizing our data using TDIF for the text based entries and finding words like *death* leaked into the **SYMPTOMS** column.  We also were able to see where entries were duplicated using pandas to show duplicates.
#
# * If we were to train a model without accounting for these issues, we would produce a model that would appear on the surface to have high accuracy, precision, recall, and F1-scores.  However, we did our best to remove the bias from our data and make it fair as possible to train on.
#
# * We trained 2 different types of models, **NMF** (Unsupervised ML) and **XGBoostClassifier**(Supervised ML).  We accounted for class imbalance by **UNDERSAMPLING** our data. We also did a **Hyperparameter** search with GridSearchCV to determine appropriate values based on the  best model with respect to F1-score, precision, recall, and accuracy.
#
# * In conclusion, this was a fun dataset to work with and helped create a meaningful model based on the COVID19 vaccines for determining the probability a patient with adverse reactions to a COVID19 vaccine would die or not based on their symptoms and personal health history.  The model has a lot of room for improvement, but gives us insight into some of the things that appear to matter most for patient with adverse reactions like if they have to go to the hospital and how old they are.
